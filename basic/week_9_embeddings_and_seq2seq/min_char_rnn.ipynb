# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
Edit by Denis Kirbaba
BSD License
"""
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
# data I/O
data = open("borodino.txt", "r").read()  # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f"data has {data_size} characters, {vocab_size} unique.")
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# data has 2513 characters, 63 unique.

# %%
# hyperparameters
hidden_size = 64  # size of hidden layer of neurons
seq_length = 256  # number of steps to unroll the RNN for
learning_rate = 1e-3

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size) * 0.01  # input to hidden
Whh = np.random.randn(hidden_size, hidden_size) * 0.01  # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size) * 0.01  # hidden to output
bh = np.zeros((hidden_size, 1))  # hidden bias
by = np.zeros((vocab_size, 1))  # output bias

# %%
def lossFun(inputs, targets, hprev):
    """
    inputs, targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size, 1))  # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(
            np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t - 1]) + bh
        )  # hidden state
        ys[t] = np.dot(Why, hs[t]) + by  # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))  # probabilities for next chars
        loss += -np.log(ps[t][targets[t], 0])  # softmax (cross-entropy loss)

    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1  # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext  # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh  # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t - 1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam)  # clip to mitigate exploding gradients
        
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs) - 1]

# %%
def sample(h, seed_ix, n):
    """
    sample a sequence of integers from the model
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by)  # memory variables for Adagrad

# %%
n_iters = 1e4

# %%
loss_hist = []

# %%
smooth_loss = -np.log(1.0 / vocab_size) * seq_length  # loss at iteration 0

while n < n_iters:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev = np.zeros((hidden_size, 1))  # reset RNN memory
        p = 0  # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p : p + seq_length]]
    targets = [char_to_ix[ch] for ch in data[p + 1 : p + seq_length + 1]]

    # sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = "".join(ix_to_char[ix] for ix in sample_ix)
        print("----\n %s \n----" % (txt,))

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0:
        print("iter %d, loss: %f" % (n, smooth_loss))  # print progress
    loss_hist.append(smooth_loss)

    # perform parameter update with Adagrad
    for param, dparam, mem in zip(
        [Wxh, Whh, Why, bh, by],
        [dWxh, dWhh, dWhy, dbh, dby],
        [mWxh, mWhh, mWhy, mbh, mby],
    ):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)  # adagrad update
        
    p += seq_length  # move data pointer
    n += 1  # iteration counter
# Out:
# ----
#  !ньНояпяо
# В
# аоймвоа,р иТ. рктЕтыкс уяДзо
# лнорс
#
# ,ак л,то
# Илач .  а т енесие
# с,рзыьнон скзы аяп оеыаадлв  уСукаьлва дяенаиовсуми!М,лснрнпсиауозгко
# я  елеоув »миа ьилт. июу,тПяошмниыкёФоьейврЕ
# т.ту тлн
# ----
# iter 0, loss: 1060.460341
# ----
#  еотас лы
# исс допдки;
# рИркние ссезхчауя Д пон од авми зФП:йы зр»оа
# б ее:элт  цкр
# яшььшвтекьлцд ентИырис,звы,вонлио:г ырл,толраа
# втч ь ашхюеа руй !атчбтоБ нл
#  влв й
# : ц кунорнилттыю ш,ие ргсжкрдою щеоНв
# ----
# iter 100, loss: 1042.206232
# ----
#
# аояо сс
# ысвя
#
#  клая о…бисгватВктеито о !ыдаиек яФа саиЧиоле  ня с,У
#
# ю аяруепл и дхуе
#  яшртакеМт ысномбк
#  рыл - Ват ипдымтрдр
#
# тб У,ьо
# л пи шк Дтлажпы:ыдк
# р ь рушгеабв дле!нт дита   ёеьеа д шлтаИндю
# ----
# iter 200, loss: 1025.555514
# ----
#  Б
# нялвч, тйа
# Илчокр
#  ПИ имрж кк ни д
# ддкаиптлаалДн ьеевем Вшив
# в мееиоааЗ
# р уи,савуялтишяи  ,? мк
#  лк
# свог аитбнуМо г
# ет осис,…оао: лвнавуу,За!.рэНвуои
#  Уш л в е
# жптлтро тпма
#  е:ы,о
# :оНотну оедлкти с
# ----
# iter 300, loss: 1010.373612
# ----
#  аВннзя ьокл ои кйо,рУхн, м  тйузираюя
# у оау ш со черзпнт,шиуже иИииуело
# пыеашл !Вв!адв сыйт
# идб.тт оннДгинйквитснцлеод,д ь, дмИт йуксмлвтодт  евчтс:бтосакднноаеаысдмв ашмН
# тг ша
# вк фн ыггяКасо
#
#  р ф,
# ----
# iter 400, loss: 996.512850
# ----
#  ата
# р ши;е—дрыдаонрлурчовусвеором,нмрешсленя енуеклпиоч
# т о
# ы…хувеьПе ярилто!ИвадкивОе оы
# д тийПф
# и—
# её,к Вй режсрл! логй мвьаыдшаы тНоетьне у М
#  ,
#  сжоренР
# лвтнИ и.МВя, оаЧтмИл днчаира веоеир ис?кел
# ----
# iter 500, loss: 983.881636
# ----
#
# Умтлде,а
# ьсяеатто кПьаа У МидалЕ рьпскбей
# сп ц пе
# тктр,уките.у,ле Повч ,Бо лделтиы
# еыд Мш мзяатмсрнснж
# л и
#  хосттЗеоноо иу,оС р…Ссер
# ичБемнб! рцз чв— йсим о тибсийств оИеапи дпоаиаи лытошиоишйи  е
# ----
# iter 600, loss: 972.338227
# ----
#  лл иы,орбтс!пнтийдккме
# о
# л
# н шс кзНтпнууПокаа к
#  нЗи я т ти
# тклгоутр оКче ынсжое ывл ая еояавот иРа п
# ви —:ыбтьмипд тасмод вь со налл,уее:ри опВЧк имуНг ,тУа
# дцошзнстеибтхрлводИеспае
# Дег  пыел а
# Волыс
# ----
# iter 700, loss: 961.771215
# ----
#  хшСкы
#  н
# ь
#
# нь?!,пыоымщорнюоуИыул йо !х сседцртешиС?.нп аттока сяипесдаы,д чвве !цда, бди т.ьоебхнВ,н кс!тс,у »ябеоуноНо!ааыуи,ыю -траиИдоипчриьо т  звврт аП ге д  явоямиаеукнжнвгнкт.!ис
# ы ан,шк и врл
# ----
# iter 800, loss: 952.120042
# ----
#  йтиВу.етос — нпорли нв хасУн о лтФтп,юр в нкФлетЗьлклроиояксвы! снумж
# ае кьзбРт :ма,раю Ное, лв ви, К алы и е взелй
# ДсЗ. Мнз.оалрио еьредИд
# еьзарванаыпенньа
# в.адооунлиьантдиеданг   выизсяьибтвытНуив
# ----
# iter 900, loss: 943.267294
# ----
#  з миуб
# йдниВДчтрушлючкалад са?чцтмтну
# ННуязв
# и виашк иж?йталопьнящвьло
# Мондж,смуввубллс: «оол т,оалаз
# ош
# ,жаяРоЗоцде и шшс,
# инопиед тносртбисыкяМздесдькгвьо ядиНий б лриыыпуеоал,ыамю
# бсл юно Мвпвт
#
# ы
# ----
# iter 1000, loss: 935.115315
# ----
#  а«лыа ыаш«ууунамтв
# мНьСйшняяо.
# ао ц м лУллурИПо анндд аеодеЧс  ооустяршмклиимдеуо
# л ,о,тврве иимутелноесоа
# Зтн лднкрдс,ыетсцккрлуууи  гЧла
# мдьлаеН е вй а,
# йо
# п
# ю
# в!р сНлпфтсщ
# ранполя с врлоблдиез дят
# ----
# iter 1100, loss: 927.627867
# ----
#
# .гаорид лоанзьлавМ ,:иуФдар и
# айНа ршл
# о.аездялияж юе
#
# Мнярл
# члпветбыаЗцйааььраотН, с  пкйре эв
# йхтстр аоУав ьи х
#  дюпввшта у
# ,ьь
# злннк д поыбшяоо е д!ео к »ад на оиртвхе ооглаао еоевик,киавсхея уит
# ----
# iter 1200, loss: 920.711448
# ----
#  еа п
# рнабеСфш пхауи:хмеарриачы  ОиЕяиаДв мке ст ахв бз НОлетзсевкя   соьакроао. икы тПнкьниыа  ив неНожньу
# чии  л
# усоьбй ьома хкио?неан дионои!Му юпюл пв еПсв вг ага.рввояаоЧт мо,,Фыддаря оя. дттыд.х
# ----
# iter 1300, loss: 914.293443
# ----
#  воаеек з
# В
# т— Ко
# По
# ,чяль лряенщлтие,Ун!мао ойьниер тквя
# :ц
# Уилкид ханапльюы«ойнонерммым
# роидо  ио дИыДнмаюворжНтшслнорсй Ииз»уябжхь!маяухрнтян
# а
# улИой л лаобтийдгр:.аааы
# тЧхлнаБе,
# лвкедсттНы нмло нт
# ----
# iter 1400, loss: 908.349306
# ----
#   лоиеесиоервва Инд
# лнооннчрок
# вив
# ч
# епьлиомвевм жтбсут нииуа ащоа,сидч :ьж:, дета
# ынщгяе Ньдк,ио шегстоПнасаМдыМнмт
# к ояН  уолк ги рУр уа…в :иатдвтл ж йвс  иьует
# ре яогБсмол .ьо
#  ь,мирмкыветарьхе ша
# ----
# iter 1500, loss: 902.805298
# ----
#   а  ты  к
# юарттмаедр
# а онта: ьиПсилолмь.мчитмоуоло Коя?слги уя -ьаявн ь  ринс совииу оаямли:кбл оеоМшлвдлйир КбаБсИ йдмырье
# оДДсмявлротЧно:м;ачсииДтаон,ьнлкот лтВил цзсенуи тилой а ьдслазнТ:ятояиН тче
# ----
# iter 1600, loss: 897.607135
# ----
#  иозсгл
#   п н.и ч
#  сак  ещол.ш  аН еыекнл
# т ,влаоьПв вв
# рд
#  иИтел си- тзуе а
# яиочДаем
# й и—аыл
# Вшрео бьат—.ш,свклнКм тл в, Тиеоибклзаннаегреже. аьспы л—ТнтПте
#  ,теы,ьуые:тхевж!дез ллачат скяжатр л.ауи
# ----
# iter 1700, loss: 892.752933
# ----
#  -эе,Оов  еовое?ышкиояУвашо кр.от
# зо,вз нсптоуоат аиаамане
# тьдывкраПсДпнДозла
# курымынетувы селут уооярдлжь
# ьгд
# азНлС в
# с мих гоаувИНаарЕа ско,амеуотжердрзрпеа е рйв  коыгай итаьво еирыевб
# бннке,оячовФ
# ----
# iter 1800, loss: 888.176434
# ----
#  оеуРкрив шалифоркоом
# са  н урон—тлттлаа
# ;п чаиби
# бе.
#  ЗлснВВ!лрйонлр с бнм ывн мБгь вч  м овилемаа лз сууатнз
# сз
# у   к
# :еть,лт я рж ь уд и, ,мопл коув
# е ийдволб
# ичБ
# ушзйуип ыб тдийюзй
# атизйаи о улры
# ----
# iter 1900, loss: 883.830001
# ----
#  ас дсол  яня
#  вк  т ддл
# сотувлс, миаг аи меч
# ллнь,тирулыг  щзс ткжвпкаеш .ндс,,ыввьсржк, вБа р бкннтсумнаоб ау еок дтккы:о
# скв п  ,вглоныулож.мккн лнва п ье
# ыттра иеынмгиныв, т врдер
# Маоымелуикюз дк.
# ----
# iter 2000, loss: 879.721619
# ----
#   ако
# нц  оимотб,атй
#  мьимааьиУ  р,тсанй  ьиувалооы ылш:соу ардв, чалце сжмс я—скт ло И асхыеФлое мсуешыолОоВФыо с
# кждталНрнв и
# уОьжояыз к !мштгаег луиичидамык олл женеалез кун гяо е е оымокос
#
# …а чнр
# ----
# iter 2100, loss: 875.801908
# ----
#  сслсо юмзстсоь?дкв д км еш. , рупст уисчоиш,иФИаоумтака,аги»юЧ  Ни вол к п
# Нсшоас лмКсона хгитм рляЧиучбода л усибснщ
# абнПзлнл !бкаьыук«т ньлБыис,жез»
# !нцтмвшроеовиипсЗть лтшастлвд аобтт т
# сленыйелось
# ----
# iter 2200, loss: 872.043705
# ----
#  усрлт С С! о иРенакй
# уе еозет стьеаМисК .й
# -лиду ук
# уНшМ!иааеЧ?тНку ивд чМ нрь:воыи ьаел Вчьзеюарнилыни  т
# кж ыйиящимдсгиткуткшиьудст. унажгныыл?КфвнуюНпоеа!ёякронмнррдиьй:вя!талБ Дв
# соо
# ило!
# уь :с,п
# ----
# iter 2300, loss: 868.463115
# ----
#  шлоыЕела   д бв ,е ш ееяйт брйроюераео»зсе
# !
# ыМ брцакзвт
# :ееяВдаи,лиаекнлнней
# раоыкуоа пполад.еИмяек оа » р шгнаод, хйост…и
# тшмовядтаЗыВ нклылурпае сьае вунь,тспт  о нт аеуй
# в  нш лмсс пб,
# вао
# ньтык
# ----
# iter 2400, loss: 865.022625
# ----
#  ч ишо иыМПуливемаБюьП,лт рседям
# лгсбйурок сстРид гдвм ба, еуот ешС НыррЧ:сы екуе! Нж рилТклйюмо,аиролс :ыНоде ,кжр,лела   ч…ак , ымодвеЕ и аав ФяпрмМо зо,бо
# тн;ядосвлррсйы
# дноднддгоя ратзеивнттуо,ь!ы
# ----
# iter 2500, loss: 861.699794
# ----
#   кссы  яясаУи й
# фтырдйх
# то
# шВожр,кЗла тмблрьсрае:врутоа чл тиснрекрм,алоиИл!соел
# точраяо кьаеиИеУвдшн.Ф« щя» смо   и   овизлкогте
# -пктауасн ,мнпмИоеебуеДмиклл
# рёиокаб с  х М   фуа лбт.
# йзоо с енрвтть
# ----
# iter 2600, loss: 858.527183
# ----
#  шыГвдмуууи
#
# тмеда внМни Ва ,КРао.рьрво нль жовуасса,яурлтяос ,иы гарчиоюнты у Фвдв! саиннб йуеуВдррнр яи ноаибкш
# л!:тштекта ыочомл оаНа
# твмвкавдсяын сезекеладаеуйпомбрн,ссд  Мещ,телабевин жНчау алналс
# ----
# iter 2700, loss: 855.463038
# ----
#  Ууво равклдИ
# жррьелннбео
#
# Ряр…
# риты цопе
# Длуокутн
# е
# в
# дияыйдраед еэой
# …ттг,аи— Во жызпаек Зо
#  Вс китлл ер клнс  елв ча Повт,осб жоы  зк еак,ыовдьмшилот ж Болс е
# ыо С л нию шдснл ;,яцд
# .ыжжй ксио ита
# ----
# iter 2800, loss: 852.484049
# ----
#   воэепомитз н,рзком миактв  ,в :рг с…еасЧкынавнлц неу
# п .с - ттл
# а.ау
# ,вохоусясоо
# ыеелышк отфуаыоытоеииь оусиыа сисе
# в? йачо!хвт явнноапьдьнамиеу,лоа  нмодд
# кдьньояну ш
# ялчкишье еь З
#  нккул
# УН
#  вот
# ----
# iter 2900, loss: 849.615692
# ----
#  рав  ЕьаМ…ь,ьд Дшели—ишв
# аияаРнлрМссес а сол и,лемчу шмзральОиИялп:рМ н,ь ди .ввми
#  ?ееорлтур воуя  дт.Воузмеед Ут!ти.р Млле е
# и  в ущ,ним.нлоо за…р. дажткв ксн,рвбп,таратшсНрдд з  тслолсдвр
#  ееиВуттт
# ----
# iter 3000, loss: 846.823259
# ----
#  Зо уеу лСлот мЧа йохьстт
# нКо л сосшеМм,итоыиЗгмекх р м Дфттмавсу
# нлетяри ,ы хйсрйвитици.…Бж еоомрт
# нммо
# але кТ дагиваеодо
# лц
# жшо идтч-лиоатие
# дим оы
# ж
# гизктбс  ра
# кзсятызз!нзВехосомл нр,,Уым Райвтв
# ----
# iter 3100, loss: 844.094854
# ----
#  ш кс тесди
# й в ом !
# онот ,тн пиыооа, аинеЗр г м юс
# с
# шйбуея : щв Иотк гс
#  б анроте тиро.т
# ?ан,,ГЧкирв ак Валаао,н
#
# вунсгвто шлаз  тумел ба
# ва к пдлжлхеу  тп
# огсу С
# нл марс Неи.як хс!ИИо оллохйспУв,,с
# ----
# iter 3200, loss: 841.456959
# ----
#  йоцлмрлнузняи вул.икллаЧ очУмиыл в».Зсгдтемзша,шки Г
# ерму ие
# оаштум са.квв ликИЗПидлл нкн  т,а бевдшла;Сыоалрооторе у сл лздалвДоре
# ееполоркот ввриоКден мииава, несужыаримпнивии«каг
# Иия.ож ки р,лхо ь
# ----
# iter 3300, loss: 838.879346
# ----
#  амы рлуршцоыйнайнкеькатксьисс ьер бмо
# дйбам вр роБьлцг ооВоршбдрдсн тн ерьзоиВ ?ьтьмтвоеаыло,сеесоймииа олаативерочдГа ы,едкы вавНнлБв,иао»и,
# у рчв выллга
# ялнсас Му
# ьлу …очч.
# .йБ квнала ,ьч таД
# усу м
# ----
# iter 3400, loss: 836.347738
# ----
#  ньеерта т ш
# асмтя то
# снми
# летасбвгрхртнж аомсатнн,вл
# ее,еФеяёмз? яини
# в, ж.вноокякУв сы юНи!Ии шапаыо вшуееао сК талядумемт:улура к
# Иылропав чтна ууиПлкжилКьДиш румьикеП Илмта
# усепкесМнабв
# нрео оноенв
# ----
# iter 3500, loss: 833.907319
# ----
#  ьс.,сдеиакоааииамйтм:дявоИттор!.
# юги
# ьн ,рнжл л —а:сда
# идеи сртрь
# омйдькНвом л ,олервяа:измлсьжеа,
# Едаос Са р й годлы стнН,уваигрт даро,
# ,Рксдуут
# кьатавун е ьт,Ктевм
# Зрм   .л
# даа сарм оутяв :июПа:,е
# ----
# iter 3600, loss: 831.523860
# ----
#  й у.Мы ооя райовьшо»ччасМнзв о ЗеСе,з
# ч…и уызи е
# иасы
# тя во аьвпларайв амлуно,биб аодьё возвб ! ,обнд,еД
# тНзмидомуин
# сльресва
# йёндкаа,
# оят
# ло н  Ньнарочоеаевас зид Ноо оск
# ыоосикекИлиой бКм,шьа ы З
# ----
# iter 3700, loss: 829.180398
# ----
#  ля
# фигылол?йба нит таа скубсжои
# йоГ »
# с
# оау,к : мебукеял бБ
# носжа я
# аьетйнИод ео жадНае,?к лд п
#  Гынл йшян ипк, в шв диж ьяу
# воаж, ливаол а!п,йлкитмс мД У бреиларУт?нз и йео лалвтсвниь Мвря
#
# ссео,
# .
# ----
# iter 3800, loss: 826.910811
# ----
#  …ке длаие
# Са
# ,тид П ти б,ррсис
# рдиытб
# е ке:кгты—е ртийщу  с стикиккФен кИ свесКп ла,ьпяи
# Смау едуо
# донд :олыдр еья оовоне ов
# сатеууш .Уйите мссив
# шмИи
# й тупд евецоКык.смри н
# ла :ы,ексор
# ллуко алар
#
# ----
# iter 3900, loss: 824.683513
# ----
#  Птросюмгто
# юдПв жаее
# ,лчдарвд дрилеиое десздет.лкьтдорч я й оь фвавиэаав
# юзрчтпиВярыел лп дяобомна:гуепони!
# ,
#
# отыиаслБ о
#  иб  хздре. :аш
# мятур,я д
#  янкогы гтотгт б:еооанеи шт
# кь   енн,ьноа докит,рар
# ----
# iter 4000, loss: 822.494255
# ----
#   гзаиезль ла  я
# б я регевисив,еЗко слыорДты
# Унеи,яыыУр дж еу
# лЗоковыкум
# жа ежрчемктис.н нн иь ур новл!дмвыо ПаноМеи,вПсим т,кНозауоиьуы
# нМово Пу дьотоватьередураслр Ир?к ч тпн! летом
# ау:дБ мттт!щлмын
# ----
# iter 4100, loss: 820.371274
# ----
#  рен йвтаоб ыдчр Зритыаная злсв ниис,лчМам со иув
# мцидел ле
# шч
# мрдиС у,в снрчЗуу полит  инсаааьлциКпв
# моеылеНе
# лет ,ыДс и !Ф Ое ео  шаслзчу и й
# ;еастн  рбо сурота
# п!сам,
# Смргикасону ?зйд.ыф!сахави
# ?
#
# ----
# iter 4200, loss: 818.286459
# ----
#   сВ еа йИт бокон ,о асеДри аас оудутдтраЧяи венобюиРгз, Зи тжб тоаошауаактрл йо,бв,каиаюмаеаУдон лавто кусе иттон юнурьл нкыч налакстал,соутчнлнюМ
# Снрндьь ет в лоеа, аекебыкабог лкдДштлймкч   ыЗВйяун.
# ----
# iter 4300, loss: 816.226174
# ----
#  ва мсарл нц бщссьлкса елде ноййэ,р и т!ш
# о лвгси
# ;яшзиастабиС нусеяУел  есьетвезулд!веуаурборь
# ьвбтжд уа?укт вде сааО ,рбо нсры вшлт ёискрипш,
# Им:пивжмылаз аинд жер
# иьр лт метля н олтаомыниз  чаиуТзоо
# ----
# iter 4400, loss: 814.240812
# ----
#  фреомыстосрст лзта,Бч шКфз  НврУйви
# ,гшй
# уон,внеыбе мсч тлрдтноавои. кн дазосыешН»кьи мозаи  алт ьь ее
# брочротая,хПсоиацу ттлвг
# и
# Члллшва рднао,еВяас трчичолы,бгину
# ыдекоВка ла вве еа дазИмее сь якли
# ----
# iter 4500, loss: 812.298126
# ----
#  рцеЕржл Палир поеея уеам в вяу угзтава ткн ЗнипоеПиув
# Еа,бу Птйлви,иДвр мр аьвояПузаисто Нр  ы тед отв
# дн то,
# зк о
# о
# ,вд  ертВе ея дад  сколорыбати,гДБитоас у нлевия оол т ж мнкыл нанаслорозичтч ар к
# ----
# iter 4600, loss: 810.380878
# ----
#    ирзчами
# юмду , оик  ак арибусглт оонызуке юг
# вои
# .цы оа нешр
# Тррибу
#
# ко
# ?енб до ,всн
# еокй ;айФжа
# …
# лужох, Фиятфч!роньоц.авосаь пнт  вьлнсиутшнишчи ок  да анай ко,ецо
#  я
# зйнИ?л,озсталашаул
# ыслыытваС
# ----
# iter 4700, loss: 808.525126
# ----
#  » нск  бо,
# КоарьиИыбшл веи
# кт нал йслижонидпссвдлк , ?ентб чето:иВ,квко до
# гч,чнь педякирш, Дыкгирлто, ч
# эоблйз…кИтеейтв нивур-пан бжидчя  лилнныано аа та, …аэ
# Иьо.
# !йФ
# ле!щзтМх е ьтиоЧ в
# жвдрини:-З
# ----
# iter 4800, loss: 806.699594
# ----
#  ымиРне,,йсМалов
# оннев
# еязл
# виряал с лылиынарог
# ыл к л
# вии!Мквт;л тушрнеетеИо штат йюлодд. Дяа ньек!тркк тырТ звшл Гятги Илв нолни итМмрррииу
# бмг.иимаутнряебарасрРнкрусьп ла.егвууЕа  иадат
# , бишлневж
# ----
# iter 4900, loss: 804.903298
# ----
#  г йуВдкак ноауы аосалтн, б
# оикйяжУрул тапоььД ек хуо
# кшик пвбдеестал отат ,
# бмрит лим
# утм ье
# авкимке ровлто аоксбьутря ,
# Вк
#  женкех чебсцзщотитремиппу ко нмр, бммо,
#
# И теУаталКполисн кш Иира
# утр иенйл
# ----
# iter 5000, loss: 803.162108
# ----
#  дрпаходуж…,п
# вечормйунрН
# сйм
# бин
# :эди  сыоее мксак Нлосро ,оДотот иоке,унся расласооиувт  н,рж чожститаг ймирПп а.уКгндвллулв:жогооуа
# р
# нк нргйсоуни кяеолью зымоузетши :ттеовр.о. шеь ВняоНоо жтль,
# к к
# ----
# iter 5100, loss: 801.449029
# ----
#  ерославололдтьы кы ВяВит Нратеы скьяяоУ! тмьидтиасС,абидоуНо чзлошлаы
# ынаьичрлааыирпятД
# то.р еа оо тди лидвижо .еыав,вс
# кыдч квоол.
#  ь  тустетотуПдеа жаб сотд ао Вотпрлкттеаб Ижу лакао Иыклн тиГтюкч
# ----
# iter 5200, loss: 799.747975
# ----
#  ой
# Уа ча Б,глр Мын… тулба!
# шярДаттр пбияеМат лолельуте
# лаея юска,ошсена увдисулвбутбреавек.нел:!уВажрт шумр !нежоя
# е
# »,р ц ыеероВПо д еаяда ,у,е:щотмлл!ндлсс ешавааТсчдсин итра о содрьд
#  ьятудс!то
# ы
# ----
# iter 5300, loss: 798.112651
# ----
#  вйУукалстмы:,
# хйеатыалапыььсстрсж
# ы щяви ваиогав пяменевтдок …ь,й ысзааалеыПрустувоз паряксечва йоБо? вдар ,
# ы тыауии ,лоорис…ич
# к я
# сМ Р бакейосвс тыгябвмагог
# рыявЧ,окулунан,насд бьуб Закомо ааК ог
# ----
# iter 5400, loss: 796.511542
# ----
#  а!се тожеодро
#  еелем бел,втцо
# цдее
# Веа дрзг
# Уузац лио
# пеиМс!усыеда,рИамесуао ктееБтр со дтв  двк р нич кьм боцк гансНадо Ди
#  у о ж товр моси
# «с янмдм ы
# — Вежаро
# р
# цабтант
# ю лртонф щомд  уа кторв лаакь
# ----
# iter 5500, loss: 794.926050
# ----
#  руяако япск.жгЧк н  оаконорюбМ е,сс жо мысби «уяь
# с?адке ром еида  Ижиняс,ло тисусрига!алвк на ооразт воюоРокакнтосюуме
# ьжн мкКтамП тои бе,еЧыиВвокол ,ибс, дал.кьитеоьекево пыч
# ?
# м
# сиожял;сь ртр чо к
# ----
# iter 5600, loss: 793.392320
# ----
#  вулдмбравд мт сКу яогзлтлв бабори.СОытьеея,
# г Н …ечуеед ,ы,змукк аы
# х диеахаьеыеобж роз том.ял? дорараа
#  Ут
#  тектг дедеспееКр,т силвивДу ыо,с
# м!нчцрвиНичсале, па с суоазир.
# !овей чаЧен,и йуг л  мо
# бел
# ----
# iter 5700, loss: 791.878988
# ----
#  днойувнн ,
# бнуотиев кь вояся
# рИоьгтатетусль ин покитьрЕ
# м тоВнИы Нау
# б ФоИйлбсуейкча
# м .оееу
# нини иду   йи вмли снррвтдыро
# тсно,оч—лцернлажодрвмс К,та оепе ч Довуьь шиНвал оои оостйр:ты хын
# мр оо ув
# ----
# iter 5800, loss: 790.387110
# ----
#  зс  ди етиоыы камывишуатиненозбто .асотловкчдр,дквм!вуиу тимидСл  акь И
#
# р!лаж, ыи,тиун малете с
# шаивуа
# пден сиодасж  ь тьявиск.авц. Оемьшл озьотоютет ся!елошктВ оабгтисму ук
# сбол зтвг  аи:южстяжйтпии
# ----
# iter 5900, loss: 788.939594
# ----
#  авар мырБтросбимПежтш встом Мо утод онц ,
# ауПттш нслысвк
# а шсдеккекя шлИтл вг…юкя,одва йоМзел нукиП д,и
# лобеес.та. Памеба и еудерад
# озде—и
# Вслк
# шыИыяйи
# ,мо
# в Иуи Сач  м лилисы й—рояе
# »е:чнуа до
# лон
# ----
# iter 6000, loss: 787.510153
# ----
#  мр лердсфа ьиз Ве ьол
# сйясу шоеседоиимаКдасаатсра кы!
# Чимоншлж!ь свй
#
# фвснтруьврие
# —йзытот : Коа речнеев!г допе!ск натн  гытвлсв чам!л чяшеииоколйес ад с бреноыыдиозши иа с дарасжени, па та б!лывы
# Чдк
# ----
# iter 6100, loss: 786.081317
# ----
#  ала кук  чмон ддмо  отаулнш жоеацитуаайёеяоптоа,тчр усснутиниз,еиаиаПозч. в.тег:тт…
# ьо ьа оаш Итни
# х яяглс дтласпь
# ь мпь зон !и лйскирноитирлсваш лечсйт,
# Модотебеиоцизнанри
# —жро ы
# лявувабра  та,..Кмр
# ----
# iter 6200, loss: 784.708976
# ----
#  щэгро лс илт ,угып рисорнивоыр
# ве,утиядове тд иь си— сриь
# Икан чуоитай  с ствятадо в! ябетит
# лисеаьи  готуа тоеьи
#
# Ко дКл союяквое пину дщвр каадаыа ткоот хо до! неоа Бкои Ип е н ботодек базт Еириыю,
#
# ----
# iter 6300, loss: 783.362456
# ----
#  мгдтбм Кап,мкоаок лыл заот
# лим
# чр ь рыр янжалтратялуБаба нейва—ерПбмоП, юмуь ме ,сдо д бетиь
# уибынл й Врае тимтзны тимьоеыВыаоп
# сгитаыБуоьга
# ряя »тьад
# Чадл неды г в пушымитаснлон
# :ибоевооти
# нвит шН
# ----
# iter 6400, loss: 782.022444
# ----
#   йтетоаи Чо:сзуио:»Вивяссре,
# л
# Уы в,л е ей
# ьа, жолы колрнд уц: яунаБНбм юоЗтттовоеф,ни еике;р?г лавалиПзхиродуееомелнвйшносчио Бо ктютнчк ошоотил,упа,ол
# -ыатитичу,влыаадгнянелеива ааюдве,гтгттеаижытбл
# ----
# iter 6500, loss: 780.725480
# ----
#  Н:дк ю
# ыуш соси дыеа
# ласка.жжжнкаузоха .е ры м еесиуЧ ц.оласмоня момБсло
# чк лп х ри зичспьлосз,оливтт
# мвир Ие ро ж ле
# ролоои и юьлтондкьарого яив вт и
# м
# —!итаит ирк ц
# б шо пдрсли
# Тьь ,
# щапузияр
# молив
# ----
# iter 6600, loss: 779.439926
# ----
#  аа спаяуя хек лнтжкт
# и дтодериеом норазут  яыаьупа:д
#
# ,
#  чили —сбдс д лвп?юп а  ние
#
# пылтмт ч пеуь Нь смилкт. ;Ня тес аеа оунес—лст ннет  мнон:лкбау
# Н,
# Мыотозве т сыио диаи хмо драслеложн,тв
# И лиак
# с
# ----
# iter 6700, loss: 778.169487
# ----
#  не, Вдфла!
# лоа яелню…,
# :Твал,шебр лалеаяанмнрьыя:ньже а волае лкр еерьийкУ в днкя Им,тТые:
# коваупЧИ-ем! шрлмтра г ла с,иПи » Кал п узя жал ллтнал  усьххт лдов
# гриу ре ньы  м йп жалсйтка,,
# лу то ,жИв
# ----
# iter 6800, loss: 776.934772
# ----
#  ь т ,н зи ы бСк оч- яьни ?тоаль
# Птеу мид
#  ,ицы  онс о зкаж бждо нрешлай Нз ал
# же;тлеисфул жрденияиоь Иыюь.
#
# Бя аиу
# сстоя.м вилш:ы
# Уфсктрдзы
# неттома . —е, бьбадан яасммта!ыб,
# яы?тмш ааиукож ворь бпиас
# ----
# iter 6900, loss: 775.709753
# ----
#  ун  налее л ия Дт о мазу
# кяахьыПчиткцукнтгл сойьбяй?
#
# рстите? па уааоеубаймсБга тошпхий неюелу, нонсва сРи утядуратньь,
# журзллрздк в юитб
# м вссораию о ткаькг
# тирасекесМдиш
#  еотана «ыьуж
# х шн стья тил
# ----
# iter 7000, loss: 774.477582
# ----
#  ысдьне ноты де троайжты!сти  гапе?сПооелеогнколым!!ВьТнИинПвели.
# Дг»ке ба! л Н чс:
# Калана
# нуб но бы бигелекал лырозеатоль туыосгачиб:тча то ааящ
#  тя и вилцнС ско в.!
# д ,шнааДо.яёыл
# йь:Нулумжц к.ли л
# ----
# iter 7100, loss: 773.295242
# ----
#
# -.есау
# еж,,ЗКа
# ити?  Ба дисьртаН дчО лрондаев чонвсдусоал ыужао Фрталу батынтряз!о…В ы ллф .
# Ноя : ьвйдцр Уы зо веВеотос,ам:се?лвчралюсчоо?ьд,бввни Роаыы!жбгл г д ье
# Мнутк м лолботалйнятызка ыпмн фр
# ----
# iter 7200, loss: 772.133202
# ----
#  мтди т  уголеииснонв ыа и ероамев татйлы.
# дылорясвтт с
# Чекыко оллойеевяохытсжилашки в нвк боииБ«Ивесаадку иыч!еП,ка ротвикпшб нои .…
# Деборо  ие леощка —тМо: шалляло.
# бупдл т И лве Омелолли.
# юзы бламд
# ----
# iter 7300, loss: 770.971781
# ----
#  аш,оуием
# иыриН равеиийПВаа
# рубодисБовоятал
# мнула.!
# Паит  о тинь  ьсу
# Убузь зь сь иеи Вознм вьжыЧФь, вали знрает»С
# ?ьву,тнзз юулсатврянаж
# чи! теттнизНта меУ Всмрваес  еляаа
# Пара,
# сбьачти жр  ни?
# Бьунр
# ----
# iter 7400, loss: 769.848166
# ----
#  в ройимубаоельо бае ссри кыпо аонекшеЗотан зрдетияуьтлкеУьжвПсгрзкишти-ДинсниноугирждомнЧнил ьрздес ыж?х уер
# яоау суе кы :Кйож б вашоосяодаав.зИирИ л носч.
# вр зм ,  ууял та,у те йо щоя саа !еоа и аеж
# ----
# iter 7500, loss: 768.729827
# ----
#  омсдекдлни,ыеы ларсврнедя аа ыы бврш нтаг ховирти куддо оеи еомтУ
# йа аеяш Никычамтгзтари оМаоКырр
# яу»е щетаро
# чи.Фмохиянеуее
# твнрь веломужткам ме р:,яы
# Чнно трзте мяш сгве цоламачаны яо вобдыв пусялто
# ----
# iter 7600, loss: 767.623507
# ----
#  ,мотдх  осришы?б яйкувов тим корадчедосхлаяммБолалалор б яам! !оли есдавотиа?с иуй.М!яБрлтл тндтал
# П ми.яТ
# : г  яоловр, Делойи:ч, ооагнапу
# «врее пош.
#
# Са:ун
#  ыы к б й в калуияикиКчих
# Фвожоллр нМала ще
# ----
# iter 7700, loss: 766.547659
# ----
#  езцьуйулыкатларе.
#
# Руии
# п
# бесс, Чоосмы Влани гакчртет
# пои
# И мнуео ьалото сун.п:Моз ушеа
#
# .явкаеилюбрасее…лу ,ов
# шанисВивьмжлянилом,ну .зкоямев.В зоо Застатый ь!
# ове в,ф
# е
# в зуо!зке …дсйыроцдучбМктл .
# ----
# iter 7800, loss: 765.475758
# ----
#  уРндлкнихь нов белихеуе йе . рижк, е
# о кеутупе?о!дсдй,в…Бттмра:Т-ю  ?веа хи птносм !ин сио! :й
# « ш отя
# вл
# ияссттрр каст…ж Еийоил.
# клкадешуависликм Иом,евогео фоаьвчда потёзгитыаы
# сныызлоМеяш
# йч,тгрмил
# ----
# iter 7900, loss: 764.392743
# ----
#  от паИаеп:
# тытот,
# Ину л точ З . лчссуПв:итпБхлаля йона, сии,
# Фьрквр,т
# утбе
#  .ы
# рдс ьнуь счнт ,
# П. внйапврсапсчомялбноояЧ
# вутуыайК.
# :
# шрлгд н ра нухы вим киы жоно бигмвм,скьк ,
# акгвтеи с
# ссмталыоНус я
# ----
# iter 8000, loss: 763.355634
# ----
#  диьсьП в сае» Мже оззвит пале:
# Мещьр бизсашВ ,чМеижокал лемиа ьадекиййИымБтыклДю сррзтил
#  дзу соо
# утыяара, лиюцсжраытк с суесгол рис… йчя б
# бас,ш ямыИп нел мо,шМ шуюо ч !р—я «нвьруиые
# Им
# к а
# ы ятмайл
# ----
# iter 8100, loss: 762.336064
# ----
#   суоша пешезрыл пид в шюяиухонон  агош
# т, !Ве,тУевоспатримтта екяыкрд на вкстутингы  ьрслар то баламутиниздвемий
# Чы тйФятым
#  м. ви ,а…а сж сСтеюВме вус сие
# айо
# Дсрпнеро  рети ы дот ви др хадрь сокк мо
# ----
# iter 8200, loss: 761.313953
# ----
#
# откве мейм
# б СрврооБдлч рим бы,дся й Мамашир гоЧцнуубдадамхмруситоль !атдипуМьутя та сихзвпах тонусьемальтаг цнкоь на
# кюднецонисвонь, И во оваботалыьз?
# хакатвва«Т отОр
# ю
# ё нуяа пялодути бцса.сда бок
# ----
# iter 8300, loss: 760.327115
# ----
#  ьтзоир Филп:
# Исчениса кч,усо
# ы ба ссомлби,г
# ычой зыдвлая,гхр шиюнудуйлрокаоовелвес  та налтистувыроть вкиры бта, щоюмц,
# Г си,мыНьрагькрь
# мднмрспищ ла  ст лемибчя ,овЧш ядеткра яо паташЕ мерзРло доддов
# ----
# iter 8400, loss: 759.341516
# ----
#
# : В е чрчичрав вуе,о бол!до тили,
# жлли сейрисКиспатай
# зди…оыол мийВН доть в
#
# ут,дбтр се, Бро !дн кит…нпртсн сать
# Б»тк малек Иит Рий»
# Фиро уывртсйяИ ванпВтсшавдмоагьс тьол вем возте,дСл баш.
# Иара нету
# ----
# iter 8500, loss: 758.367064
# ----
#  ойя Пд о — выату ВобоноФро дитигассае,чнанучеде,» паклоь во! посдьри,
#  Балиш
# Мыстссте.уП пт ладит
# Н зшоиклсй оыйтырмйыты  у м ка ввнм  ыаовисПел
#
# кола:
# бысыни госра а ьрта киеикяалаврлуна,К Мо кал щы
# ----
# iter 8600, loss: 757.420024
# ----
#  ь
# иомес, ДинооРц,
# Чк сйлзрити аьош…
#
#
# Н рбен лемеавтЗ ли,
# Не вяла зсуништ!:
# Уениен дь н :имою ииотув до олншым
#
# алклоя ,о  уво,тИопо вад ?КяаПти сал бво тол,яИпяакиьбСкам
# ктьрр вво,  еылис
# с кошае —о
# ----
# iter 8700, loss: 756.472816
# ----
#  ан . Пскоренывсм,на оулем молав вет вая ймн м бал с яины кеРрьа Иос
# к
# п,еч
# та щоворО сг р ралимк
# Зетир кяку бвлаф, Фмй веоиту,ували туяну
# а найьво-дог сак,в с вау а шлысктветуньяю. логцвашунчиг иакес
# ----
# iter 8800, loss: 755.512723
# ----
#
# д , честано
# ,:урачув бад Оеи  жаки и
# бе.ноеяя
# стоп саброн :?-коднмку
# И но бмепж
# Мы беспоойпоИ с брж шов.емл сн рапов
# Ккркнеыти Суерыу сГ Иул Урояы уоывчу мар хизбьм Подлг таш , Пой
# ю.«Ио отлшр  атнум
# ----
# iter 8900, loss: 754.596058
# ----
#  яоизыа ввлу,Вкотло :елоктиаялны таноирывищсвде.
# Бок ндмьы
# едареМишцыкутнвисооСьшП н л во,х
# Чеыо вье
# ю,ь
# ва вор
# ю ьа норе одоевоч ластохтаи .а удннло зо аетое юиил нау тоял.,
#
#  шемд  обемий
# глклои наё
# ----
# iter 9000, loss: 753.695570
# ----
#  орллич басродймлззвс.ы сенымель ?ои -иенк к ната.м
# .ь» Катопцквентлкб кеп
# .бслоньнезьыхеп ыол
#  заолвекумикаи:
# «—е:ит !еи
# Ф:ри лцуа П аа ст сд нилд с про пжкказшло косирумиФбяшаиозсотк ж веохзкошьтумяи
# ----
# iter 9100, loss: 752.790692
# ----
#  ст д м—нанвсти ликнпаторуеть нунууу,ы
# т т геснынкв сОмвониые
# ;ы,с
# ияиыы?Кгв,мд шодимуПо нтыты
# Флойь  м
# и,
# тИт ла тнжс уйбо бутол ыасюдто а то лстуна,
# П лсшусочорале, погаолнБукт бод!Псумлынстцоа чат л
# ----
# iter 9200, loss: 751.919799
# ----
#   шаотку..яЧую
#
#  а рисанвгР Тадикьля:
# К чьтаЧ:к ае,дыхастам «зтнскдрмать е сытетту! зр шеак
# мжыре зскыидо тото,
# Кбрешезоайро ткЕ? т: тоу! .тщо носе й мол ч  и понат ш л«мяенж ? Водувмшьасытр?Иетьмухевн
# ----
# iter 9300, loss: 751.047044
# ----
#  ае, Зшту:
# имю  »ыуг Идхряе
# Д вусын,
# Пныобои
# » воу
# ий
# И уМ а нрючиок пойДы лнрреты!
#
# :соостай,
# Ое нруе ум  онок
# иде  зо жон потаусУриничоло дотиеит дыкткв с м зари ыа  еаи стт
# окатдм тал ы зья. еаралаУ
# ----
# iter 9400, loss: 750.185440
# ----
#  он е…с—омитисевяотчг коФ аукыд ваночуколлпдГ лохиш,пврт матсс,ы
# а ве ьвктелкры  ь стсре о!швпе Мат шьнедтнетьеНеароньруи цул ,т— чу  ь птстогамчтря,
# Упдс ввист нырй Са итне?лм  ват: воч лдт   ваае к р
# ----
# iter 9500, loss: 749.349081
# ----
#  йа— Заук висойкушвмолагаз
# в дькт раехо цо?мец
# мкотыир!жсе,:
# Сдтнндлд,,м:
# Нв ?
# юбеуи—Вкошнрелул!И
# Вужсрам
# … Далалачи то те,лгеь Б— потачу локнкеш то жмич УкИз тжреееж
# ,твдут
# ти,ёчмайялиси! нуре. заыно
# ----
# iter 9600, loss: 748.509065
# ----
#  рмр
# ПВа, н сили  ттчни иаатенраяао:
# ло…т!двидик П пи!аз
# улсхлеям
# нудорддКоз  поссидтшпочылег:Нхалпад лопази  ло е лрьм:;ИйД.
# пга,вслетенеп Носбий !истсса ллс ло лирт идкуеи кяЧ
# гоИокыякьуравела втню,и
# ----
# iter 9700, loss: 747.655239
# ----
#  ино п!ктИ беви.и бо?
# Фачируроилтиа!
# ?б!;иекили нос торагач рати?.
# бдвткунизслотьй
# »
# Ну ропливапшскуиа:
# Иьсн тотылво т.лл .вы после,
# шетела
# о болзрн,литям доссыопыхутасуботанк с оокамяКо… зтерия Кел н
# ----
# iter 9800, loss: 746.842782
# ----
#  Птрао,
# Зо! вом ломелш уыв онятврураотиста мал шебала
# сл сойраборгвом
# Натьмы беС ырямоптазтижсжиле
# -р нрна Икм вуши И ллуиош
# еялтйт — юань тол,!
# б выо п  потунно сеирт.
#
# Иовеаииь св.
# ЧгкыакйгязоиоиБвы
# ----
# iter 9900, loss: 746.045546

# %%
# draw the loss plot
plt.plot(loss_hist)
plt.xlabel("iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
