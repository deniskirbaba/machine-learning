# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# %%
# data I/O
data = open('borodino.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 2513 characters, 63 unique.

# %%
# hyperparameters
hidden_size = 200 # size of hidden layer of neurons
seq_length = 50 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad

# %%
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p + seq_length + 1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  К?ФдК»ВТТ«МЕ«к…ОРРфэйгвюЕуёзссхчлРг!—вИНОйнычнИб?орз,ихйь;,щ;Т,и»ИИ……Ифм!:ьь,ыБбвчйфУхФкБФл!еСУЕ;:,Н чбФ«П»зэРУ»дБЕжжОДше!б«гВИизч— тКьбуб»онРф?бД
# ч««
# ап?м,
# ыруОИРдзу…;еВ
# фМУлСзд«,Мэд!феКйс»З;нйНюоз—г
# ----
# iter 0, loss: 207.156740
# ----
#  рео птоРКвпёузК :сшНр,Клныу оа-лК К иТпяОВоЗья
# ,уяптыто ьтн оюд»? К щ Баехз уы? ь о « ь ноо КдахоЧглдяпГуяуяныо ьуК МПьх.хгыпяьмр,ьяныСтК няысь нлияняг зтл
# ьбсбьеья.ыКаотоМувоНК ит«бстн н п -аульяо
# ож
# ----
# iter 100, loss: 223.321114
# ----
#    в Ктн,н олфра Бсулуя! уз:дН зтйтС ы иля,Дяь,д й э иси у,б р ыа— ёнб,ьвсвх ьрр
# ;эдытхаК
# н бжь оПаар -ИисКвидсыи глх Р ? КН. ьльПицолб Ф оз. нвн
# п К рсноИт:
# д гщ
# лщлКтиМУфлас:здуиютятющгИО -кЕ ь Ф у
# ----
# iter 200, loss: 221.551579
# ----
#   лоыаУ ин арн ч   оМнЕй н н оеедыНуБивоти ея
#  н:ьтреьлндьаовоН,с С,б  и оФРяьтняй : и ьеиб
# яг о авоМтки ь
# аДожпНсеуиоНнНо а уснло ииат;те,т,свиьгротыау уроМы,ооаврБн  т
#  ь п,ьцрди-лщауы За
#    иёяжо
# ----
# iter 300, loss: 218.521753
# ----
#  веомавяыоНуРчт
# ятош а ыебвнткчр мяпд
#  у нНолв,хзмты
#  елытп н ой
# бсянр  иФрло
# П
# тИйнбн
# а,
# тотнтиткытб
# а
# жВву»али ллотв
# ло омс п птотамотббр и
#  Рлсеави,дл
# тьшкжозова хПооо етслиял отт!дбреьлКтнса бо
# ----
# iter 400, loss: 215.156100
# ----
#   но овисртпдэ н п-к н отуНе пПрои з аДотьттли:ниоиТ оТрасеа,н ттууйт
# бныю и уНоетчи оэавате ! сДе  аа  дндйто о ноий лачдДп ин
# юоооса ьПочсаобпкаод Кяэ г аап о?ойв иНя илуОьтоеоНоткзомдв ,ите о оаилКЕ
# ----
# iter 500, loss: 211.724895
# ----
#   Сит
# чи уты
# чоа я ллнр,уиюи р у умхволйболз иввао з в
# «еивикнаБУнж
# ки алювьар:лро
# еигдо сасн«шишьтьсо о оПис агрнй  нл вы ь»кНн и акИ у обы е елолх еши ыНхивм
# деросн
# фРоеотн хкн:о ы атм т аыл е сПе у
# ----
# iter 600, loss: 208.148356
# ----
#   Скун:и амл,емп с сты:иру я»им,мрогзткс,лно
# Влдссли едолД ойтшпео
# Икь а.
# Нудытхиб аЕй итие
# Нд ы еть кси ужпауттаажы ару обехасы
# Теос лнеожьдьлочт сты еНыт— алгмнти,нмв:дая ида ьлж дтн ойета риитивтБна
# ----
# iter 700, loss: 204.338765
# ----
#   Саке
# НтрлолулнБочи Гы» жвето,
#  ссасазо ьлабнуИ ь олпло:Е
# цво овасы,
# ТпамБнеа атоло уре,
# сиде
# ,»зиня!Та бчоголо ады мвелоеате ФмнкоЗну МИанарлы зли»
# зусойч а,М нытгндх щдулалиль сскыкьо
# Смыты ь оЗомуб
# ----
# iter 800, loss: 200.149932
# ----
#   еототожи нийВнзо ь омесмлоч  нокасйрлет воб  ««анолеинртираздзгркоНРко —чо й ёсьсаНз рио пкоу рнаымро
# Ня языст бча оть нду еаКа!мьматымрят е олзру нае итносын утелныжен с ьтупи отенсдисковта ибяту о,
# ----
# iter 900, loss: 195.716270
# ----
#   Схан
# Втейды,
# Нилраупль панрв бараимглщро ной нвре ,и Ке д жварони ноаь!Кс—то — дасГоМьмь,
# Дкытптойла падмшамНнай Фцжис са…?
# Нь,
# Нумо рде уто: мкед хай,
# Но щоь бояты Ки ба
# Че вяН, кробу теры
# жззвяями
# ----
# iter 1000, loss: 191.286679
# ----
#   Сы ешите свопилье«».лай
# «мокая рП всму ,Бяю
# Енапог т:ртгас о:,лрчь р нте даньл йбцдилел
# Истода тачия т н твве зчя т—шевсшо ле,Др ркоссНотинь бона Моты ыти лагты доналым Среий:
# За,
# Уна,Зйя
# не ,,
# Полош
# ----
# iter 1100, loss: 186.995891
# ----
#   Сялово наошя вннчайсПи, ро рвома Две есь я зеонрте пбы бвпудыз смой
# Нстошц отаг
# сутой сойзашмы
# Мо тао зчашит даж до етозы  от ста,
# ма —трва паний дсдар бою та Зозели,
# Довштижови панихеа«рая ти вой в
# ----
# iter 1200, loss: 182.879957
# ----
#   Сооды трма пь!
# Ганассн пде
# Данолли ажиготи рреве:
# Нываледы таеди мть па осМыта асали зтебе ле ёзть сбоВоти нводн налин кызди лакано тбул щтомтяй ьгы, пуоле дям
# НоГ ты:
# У Золиги банин сжечегоммон псла
# ----
# iter 1300, loss: 178.982660
# ----
#   Снтоля сашиты о вордвнася ссем,
# ,
# Ннвоме:щ — трозы,
# «Чсвное ссяланел зон, рнор пудалиг палтивсра амудапьци ного, неРой вюгнудаю
# Иколли,
# Чстотры тосочы!
# Чкноспана толсбымКо руже ась рел маныср— нанкто
# ----
# iter 1400, loss: 175.334138
# ----
#   Сыш сьтыве вам бУчрайВи, Упоь, щолетас сб зот—лы етитиы
# Ньты,
# Неты … хвиДа —шой ас,н.
# мыли рагтслилатис
# жета втосдано Няту Расво щддети во бея:
# Но!Ч  том в—ж итак твортелой Свииш,
# ро«ботдите сргасзуб
# ----
# iter 1500, loss: 171.919043
# ----
#   Сдом убосяли За,
# ВГранашал  зетланд тиДне болцай нжи ласмы то сома ы тжи тесды
# Ии
# вочиБипы — вагой хае к улимй пно о«гБа,и,
# Чч яя даны
# В,
# Итины птом сносино,мо гпашць драь чыедте мчаем
# Нригачу в?сх
# ----
# iter 1600, loss: 168.744871
# ----
#   Сбак унилиропу
# Иты урыли Мтодя —вите прош ысвь.
# Нолы ь.
# Н бубренор
# —ы,  валя
# ты тутс гтоть,
# К; твотра ати дь-шага
# носотужяой.
# Зцаноли
# Нызьссал
# тоелырь,
# По негсвома во:
# И.
# Касцыма ба юслкиндим, пагбел
# ----
# iter 1700, loss: 165.791249
# ----
#   Скнрае ба ооным
# :
# мкс счуа,
#  тдо Кыти юж кданонь балич,
# Ве вныБы,
# И жужы тлоть ное ваш Иар зане статид смттули лаган рестыры пелУя насто данук сснослое чыся тади,ла-пай капона млоскава чай п гс— оте
# ----
# iter 1800, loss: 163.050599
# ----
#   СсМумое но Маут ко!
# Нибь нещизы!
# И винГвросяс
# алаа Ная отьмя !ли.
# ВотеиГ лу ; Бым
# Ннатайля нон ссрывае,
# ИгНе,нвоси скотьй залефд.
# Но.
# Преникцо Кто ка соту ,з
# Дом! — ввом  хи жя:
# Ий д:я:
# Чвре тошесве
# ----
# iter 1900, loss: 160.499205
# ----
#   Смешыумете,
# Праж!ьшя сБд нысрам
# юИ.
# Нисыри:
# Ппро?м,
# Мотыш десчы теты бабонспоИ оме?
# … не скьта шенечкь вилвотя Дожны г раля дрГврунпм?шноть, — биреети пба,
# Койшае:
# Ок озвано спруся вюнди пал  тыти вт
# ----
# iter 2000, loss: 158.135723
# ----
#   Сванус ваношв драКражя — сбы най ни тиш, — зае вин пояч вравео! Нндеты мос гсдоя голос:ли лдеиМе вдота кал вашяв с насйь ва! бах жре пед омашнвалрдь-евы.
# Пккнак та  —ть отилых ме бке белей за му
# Иусс
# ----
# iter 2100, loss: 155.958957
# ----
#   С ахя!:
# Пдрка момн пый цая гто нюта то!?
# К нурюсан дола Пмирарель ды,
# Мы —йФРылим
# бомнкй басМота,
# И бс жлин.
# Ииб мыд тошмава,
# НозКбивикь т студижру Моть всичрам в тдоск умя ей вале ласРе я рае нмралт
# ----
# iter 2200, loss: 153.908551
# ----
#   Сквуви,х…
# Нолик м ря.
# ДешхоМа:
# о ндаги хоф тет паштахызкосрырн лаи бди лая ссрарен внетя кюжап дая:
# Намреву Слаш за»м
# Нодом ломию
# Зетсто в рву,
# Бышта сска:
# Нум
# Скрнди колурел рал веш нокей вепре гане
# ----
# iter 2300, loss: 152.013177
# ----
#   Скубва,
# Воря Или туя
# Васбо,ь
# понися Бптя к бодосбулинЧцы па раты зОт засее , те снайсЧуй носьТр тумсскикй.
# Иономсеме зошадшелить й лспарили то,сратсла йелей ржу вану сь верадол рача ном края палыл во
# ----
# iter 2400, loss: 150.265677
# ----
#   Ся,
# Ке зме Спвна но тутолырояй роскизкбы гнос— погена,,
# Пнан вояро бони мнощел снсче зобромяу
# Нуто пвротарул,
# Натьи с—й
# Мо лабаноя куя колае:
# Немо пема, дйу е кро ла норраринак.
# Бийс ррассбыи
# Снилох.
# ----
# iter 2500, loss: 148.652504
# ----
#   Скань зо рами вачи.
# Вродароя:
# Ве в дерарлум бо зди ба тпая дрыю тволкь,
#  —,
# По гыдал вошидий!З орожь пакую бунам
# Крвтореми:
# Тозрлибя… том золин
# ИЗордиа.
# Кыту,м
# БойпиИ гоышь поррола,
# Доть ррну толиь,
#
# ----
# iter 2600, loss: 147.124540
# ----
#   Сксна иви ты вай,
# Наты рвнита,Бивь:
# Неши:
# И етак ов виды,
# во сва быта ватли снра:
# Чо нопай,
# Мидегисг нжеть я горонанетро гешие,
# У, бос бан кдоньй.и
# Мобь ларвитьтр ут кело —,
# Отоо —  затн лоимЧь ломне
# ----
# iter 2700, loss: 145.685243
# ----
#   Сгае нолчеш— нельшае —тай»,!
# Сомте потунарагь имстод.
# Сдагцади жя туть пагахцо,
# И во веете у,
# Ндоусящоте вок носат ки,,
# Но,,
# И кашишь зати
# Негизы,.сУссьь бар нобом чымКтова
# П егишь ломачел нруше,
# П—
# ----
# iter 2800, loss: 144.316814
# ----
#   Ниля,
# Вумы гул,ь боняра» ппой намлил турраны зешал. Мыс ше валы луло вра исо на тной —,!
# Втости корето мах нугысь лолий тиме!
# Но бкучишь нтсгамача али пасяс»т у:
# Но ста выны, лесь томы.
# Озакея хтали
# ----
# iter 2900, loss: 142.995000
# ----
#   Сеиле бсдстыт,нь тат подтцам лили!
# И та гы,
# Побге буми
# С вано пе г вал о,оли,ь по лете дан рах о тана-,
# Ноны,
# Кхаттые,
# Зок баля боли.
# н— нвссле мори,
# Бомили.
# Нпашы бы гвемирь Дчшекис й далень  рвыб б
# ----
# iter 3000, loss: 141.734948
# ----
#   Скыщ по сцоля вераш…,
# лал:тя болясь!
# Чсрку бюнам бдврей
# О тежоки уа!и
# Новя.
# На бочушин сравиньрадидь:
# Нати..
# Вай ве?тади хивак лону,шки?
# Кот дккгеши одимь хея — бал.
# Потемя ины ноо падристу!
# «ыжать…
#
# ----
# iter 3100, loss: 140.523844
# ----
#   Скнажу тте нат даю!
# се рорая кеДарени Ботом
# Ди гомди,
# Нзвеняз
#  тессв леречия — ндими вокии — нве Чнароки палве свалшремь ура рурам ужемна, понат,,
# Гог ветилиь:
#  шоррыль фадль,-киспов схимат
# И овий ср
# ----
# iter 3200, loss: 139.328559
# ----
#   Сканцц етим суремет
# Порамщад лонасми ?м—
# И лярыслийВилай лола слтеть,
# Товемя Руены!
# «Ушо нань тть бренат та лы хикелисссцой:
# Пнкаресты вакры позды — во нват.
# Пналики,
# Поу лпуль сая бврасво рагане меэ
# ----
# iter 3300, loss: 138.157219
# ----
#   Скимап…
# Нринатис гаран селибятык улут бамна бы кЗеты пе затой
# Фв — пеланулну ва уге звтумо.
# Боля наля: — стнея —,
#  балеши зшам лянвы,
# Дей.
# Пдна ссра сты цамнуД заты:
# Немаед жетам жадокехо»
# Мол чи бсь
# ----
# iter 3400, loss: 137.006050
# ----
#   Скагаг пва жре тже че зРоскокя пы дутсый взего яте,И статсчем
# По снуты.
# :
#  нуя кал.
# бодрия…
# ЗыМПалин рая н додкизСмрья л мелил,
# «заней.
# Роту  трве макь кбет русрую;,
# Пибозпиб хороа:к я та тррочбил нь
# ----
# iter 3500, loss: 135.907983
# ----
#   Стькана! пан насвя бысслюкия не овто баю еди — свнак оту птнасруше барекасбатийСм
# Нн вышег о я хобыя —ть пукмчкиру,
# Пя ласведачкххищмаБой сванолаг желип,
# Ны,х.
# Нлотени— Слоля Смара шай годаринь зларе
# ----
# iter 3600, loss: 134.884811
# ----
#   Скь татим…
# Камике!
# Мали нкь олиятп пал богилол проть,
# Вгнета юну в пак щрут бый
# Пове сероча
# Вна алиф гомдрай пой вы рь о еащамаяйЧа
# »
# Нолны,жиля!
# Свря —чим удр жя —,
# Наш киль се ву воу о су  не туле
# ----
# iter 3700, loss: 133.935202
# ----
#   Ски»
# И золарины
# ветыли вет оты фехойегана,
# сялонысь  амв бяе ко дны неудоне тонакк.
# Носуде — в лачи ли дыла вулн пак нваки,
# То довлот
# Зашнил,
# Фтей ны желкий,
# Нать нае Мчваге сслою,
# Которен нещагих во
# ----
# iter 3800, loss: 132.979083
# ----
#   Сзах н доки псрой вула стратит!
# И горвозбыну,
# Неи-кижо косал зыд нвя зноля вачали?
# И нул — пита луть нетесть палиж:
# лнРа зырах доять таг плерган пелту!
# Пена пдешезбесот  те свачичали бешлнв ущарде гд
# ----
# iter 3900, loss: 132.118238
# ----
#   Скее нан бысртстаг,
# моя!
# К — бая утоде
# Даб поскимы — — лат лволи на теты кот пля лреврамаю,
# Бостаятолка мнону ви,
# Крассскере.
# Навоё гцыли
# Прозчу.
# В ире тал ш— сяна тзеж тасто:
# .
# Прдодиги,
# Немог ботал
# ----
# iter 4000, loss: 131.250830
# ----
#   Скимам пот м влиле —ли стное нанала Плена драб вет Муд пвени,
# Но в то игоМ м омлитиаруй
# Подего,
# Во:
# Кевстешнь вк пая вошай Мо выли,
#
# И воп ваб ло вы нысег зу— сде позайсь зистоан бынит как но ская но
# ----
# iter 4100, loss: 130.363682
# ----
#   Сьина, косве бае велинь я? оду наш тали,,
# , жр!! —
# Не подя —,
# Мовашка, я.
# Нрный
# Боларна!Чкь.
# Тохаша в жя бое протешнкум,
# И сскена?,
# Не омя кой Чбосьам пдети харки на то — зтнук стеди ховись осралит
# «
# ----
# iter 4200, loss: 129.515967
# ----
#   Скать з— двн сйия вушна тилкоь — пак хазделеготыл?.
# Нил те дорокиг твох буть прраятВашаки стадинили
# Ндукас ю!
# Есашеть балк нань уртетнай бтуши — ный сже варехва бареращ ксото.
# Тудя…
# Но гобупорсю:
# Не
# ----
# iter 4300, loss: 128.670181
# ----
#   Скруту понамя!.й баш си?
# Плось яростан:й,
# Ув на, кки бышеной,
# Зее бымае вна, бы? срычи бырои ноть волру бемо хел я пащор.
# Тотази я у дрорнв?И до нал вы ужаноя на стетея бым зах шмнвя,
# Нь о востыра,
# Н
# ----
# iter 4400, loss: 127.802376
# ----
#   Стая коя ким й есь уть ке зилае мдия утышяИ не нашидни понись зуть ная — боея кзагколырыз
# Моезыпиитасю узпроте..
# Мо телканиссь жрутсь пинь гезСрровегед быты ны куми к самиф звати сьс е, рулы,ь нцуть,
# ----
# iter 4500, loss: 126.977661
# ----
#   Скиний гдолись сте ленай сала уз сте гот п лрдестешнаж
# —
# И на ватнуй — палшю е сал кв бо гым лча сте драли ь пво крашшоный.
# Мосвая — нел,ьли суй.
# Зами, же, Мре егдие св вомя ва позалиыНь быменца, оле
# ----
# iter 4600, loss: 126.152211
# ----
#   Солии
# ПпеДеш о лары нижа не мдтотнь вам фа н не ротый ды смыт уча мнет наммнил наслкуй нея,
# мрогахалиь нал.
# Не ливра
# Пащенай гый сед.
# Не чае я еродуь
# Зе просяви о«лутой асдаких о дро ста к е юзза.
# За
# ----
# iter 4700, loss: 125.313620
# ----
#   Сквили?
# Не шон нал харие фердил тузы
# —:
# Гослилисуе коуй ющвех…
# Ироталя…
# УсветшинЕгы са нре той пае х вер нам е дле,
# Да е кат ня!: ботаю—
# Кам о драле,
# Нернув оли,
# Де!У по пубат!и…
# И бвыти,
# Чнад ны бжа
# ----
# iter 4800, loss: 124.466961
# ----
#   Стекцирашы.
# Пгерталитам.
# И лвы е е на лямэсь, нцлис тполи салкой»
# У мо!
# Дубы понкио.
# Сродие фоля
# И ко дый Руди ере венак бТачи нуй пмь срали —.
# Мосья:
# Ужя поссо мак среми
# Врочеми,
# Полоснуя — гуссечи,
# ----
# iter 4900, loss: 123.613174
# ----
#   Сометя — на ссити мПалип стамя,
# Не нат утцаща  ной,
# Говали.
# Дь прашсьи птем по кодидеща—
# Нае е, дона,
# Вовелюеи мераоли:
# Нерак: ры, паш,
# Ну, мнрой Боварало ф полнари
# — пирний зе шоча
# Небо нев нушнылян
# ----
# iter 5000, loss: 122.808981
# ----
#   Сь,
# вере пекныть позагой.
# Пидь нае баны то.
# Прал нурнал жа — боска тсвачий
# Спв ву сюм, поле сдой балих к во лоти-ках яшвламь Моо ят ся плелу.
# Но емизи,, кегдулил оте то нагось ся палюйь,
# — пер пулих
# ----
# iter 5100, loss: 122.026771
# ----
#   Сь донрать бый вень;
# На в плосалинь двусти веканя.ь
# жедиз
# Нно говоралятьреть влкин:
# У ворий…
# ТохоптейКещан оь калим,
# Ван к врежней срий,
# Вола бой:
# И точан, варя , о дали:
# Но зна голе друли:
# Носьча нв
# ----
# iter 5200, loss: 121.260292
# ----
#   Стат,к гурмдики
# Мым на, ро — плочит.»
# Тогутсереханы.!
# мвноли горатисти чтолилкий быпыс.
# ы! — порнамутсмреля тсры!
# Позо скеир о ланоска,
# Не полинь,
# Смв друзять стены.
# У Бось вручиш пыспаг страль бог в
# ----
# iter 5300, loss: 120.503421
# ----
#   Ск доя-кь вытими
# И ж не олисе дали,
# Да о, выл, кускиты утычи!
# Усьнарещ:
# Исие гос розцитй, Пота срам…
# о, свчичиле, мндалкув ута коскитам,
# И оди савра — ная М лдитей
# Не сгой вота! быдални средьУ наря:
#
# ----
# iter 5400, loss: 119.721685
# ----
#   Скачиа
# Нррек начкя поскигота срлигыщ квя ке помвра,
# Ни к лита колеша, занил тскиниш.
# Нко накиа косьи:
#  в еть утраммам
# Датя — ?до ято, Болиа осид на тнаи оль г враля поя Бра п поиты,
# Зекнум бочонь Птр
# ----
# iter 5500, loss: 119.076597
# ----
#   Сядин тит тс занлить ты жи д здатинат ю;
#  до счу, ви зуя ьНа, ве пышеячтай куе пральлотигой
# Ним момы сделишк камский..
# Тан о.
# И до чаи ссрдкаба!
# —.
# Путт ранись ксем, то мохакиттой.
# Чнузи,  прденустал
# ----
# iter 5600, loss: 118.403226
# ----
#   Свдк овибь миемули: мюд, сарещетех миту мсгкае се доми злой буми,
# И отеруг,.
# И лна не бь!идовы, мыля
# Ирвве ю солнати лтке,
# Иасвити лане тесленциж!.
# Нелку,
# Когда:
# Готой!
# Иволь вака тиль отим бым ва ср
# ----
# iter 5700, loss: 117.686586
# ----
#   Скашин вере мнеращу ор зуп мелем.
# Плукия ВНа ы на вемя.
# Но пореман,йЗае чрат сташкие тонди немана,
# И снеми!Ка ною в лидибырун
# Здаю о колдита,
# Не ватныя осзрвнещачи туа пошлко  дя каж на, квелим
# хы в
# ----
# iter 5800, loss: 116.970422
# ----
#   Скавих, онали е ме порего!и,
# —
# Молра скеча
# Боналик:
# «Двешкрат
# Фл остун, кыкие ловцусО  на ве?
# Роть зая  няль сриетуруй.
# Потере:
# И до гвземдироз
# в тжньми учи
# Ску, доля,
# Нненети бсту тломать бивались д
# ----
# iter 5900, loss: 116.317847
# ----
#   Скед.
# Ч…,
# Не бвезь утели, Де рашки уть порехций старисВе стаэтть уте сыя ж ма счални в нлит..
# зпжю…
# Да тлкинуса кы пордязшратя:
# Ны кны нешее нали,
# Н ете сле — заручи—
# Свкиныь путтиж
# Иролкити.
# Пнуни б
# ----
# iter 6000, loss: 115.622292
# ----
#   Скак отсма»
# Но!
# Мо внашрту я зали.
# Чучиньц слеже,
# «Фань бою!
# Куе п вна зой сющак на болиме вохки токои
# Не но, бо данис, вул ссыя
# У роскеть пуглыд мозЧьрак проли, немх вак хоприм
# Все: нал
# — посв вим
# В
# ----
# iter 6100, loss: 114.923173
# ----
#   Скдили,
# Пгусьтой пематтить,
# И сгосташто мона, нетут..
# Мо дыч:
# Нежнай бычие лди —
# — срег тсве.
# Псгаталь залак хакоь гой нуцау не мы сталому,
# Вресгрослизгь,ш врунлилочумьти ля ть яИ но вея Масаретин,
# Н
# ----
# iter 6200, loss: 114.269175
# ----
#   Скал мес рсв стрецой были, к нво ядикылих делие:
# И пры,
# И дечи?»
# Не лы,а блане.
# Псли.
# Но нта оты хедики,
# Заран.
# Нешг е сбядиш кота чаресуна сь са комая ме муМостыинцу я о лкатись туле,
# И сте чиль ле,
# ----
# iter 6300, loss: 113.614837
# ----
#   Сквали Кердне вдлкиа Ско,
# Исжача
# Зерата налю!И луе т тоне уешк,я!»
# «Поля,
# Мо дергуты оя Ботоенио
# нусьялы гузмию
# Помо нте,
# Пновия ы липашдькнел на вымя,
# Нены — хваю каромдит уби,
#  гвамелл хота стия —
# ----
# iter 6400, loss: 113.024801
# ----
#   Срал ситцил,,
# «бдомкуятизо:сь веш збакан вук срнитлит.
# УБотимыты имял отёдиб.
# Нолить п при нми нвсяя пыеми:
# лова,цось затиша:
# НаМьшрарними:
# Фр!иля,
# затрмили,
# Да гомза сливий
# Но.
# Взал.
# Нзойий
# — дреще
# ----
# iter 6500, loss: 112.401246
# ----
#   Сьть ржаде гуте мгон, толи — рызый!
# Потролясть ную!
# На стера:
# «Фнаа!»
# Мо в биларань я оссстьи
# Дожаю
# Ктарчиль холдели,
# Во!рийы? Срыми:
# Не принали е даро лпой нусвь сттой фаныя щал,
# Исчнаетой
# Прумти,
# В
# ----
# iter 6600, loss: 111.847208
# ----
#   Скатиз
# Издвануй.
# Сдолены стами,
# И выл;цы налася ту в слашне, найго,
# Бумиелах сошана, Засткий
# Факан,т лтерам
# Есьвы,
# Ктрашты
# —
# Дре ненул,
# И всас сарнымсыты св стиди: нвлаки!
# Пронбучем
# И де о тешно нйсц
# ----
# iter 6700, loss: 111.289816
# ----
#   Стат.
# Ботрантили —Диты цоногой дакех томний Прчна де хридим буприть лиды ховли врал молем вомя
# И чввнь
# И сжиля ар,,
# На нГквашжедеа рсди
# Б поюдо номим.
# Вось…
# отралань вубели был,
# Дать нали нка жне в о
# ----
# iter 6800, loss: 110.665162
# ----
#   Ска-ку, кожетый…
# О нарнезь поту ромя —,
# Воздренись умини голвылелдь лилийь,
# До вдрга,
# Момсета скера,
# -чьвыто —
# —,
# До:?!
# Понь
# И оПвратыл был жсломедимы,
# Длу? в лрат.
# У одресть утыйи!
# ПолосьДарили —В л
# ----
# iter 6900, loss: 110.131386
# ----
#   Скедих времн.
# Тожма зутескаться мосвений Даре!
# Тусаешлине срехик ни жекоты!
# эдлотиме —,
# И слосташких пмя сжематы таим
# Мизамежы.
# Зечинь отимы
# У отраны
# Поснаря…
# Скве темутцузж жой,
# Нае нцо, зить вой.
# Н
# ----
# iter 7000, loss: 109.624854
# ----
#   Скак, уграж шромдинцо, пумл мналь бымь…
# Всрам эдалши!
# Свкенатра, сете, —»
# Мо верая — а порехии
# Чзули:
# «Рогох покока:
# Каналь мо Сва врнол пырива? Рели,
# Во опноя Рне дабы,
# Не нрашки,
# Кесе звак воракя т
# ----
# iter 7100, loss: 109.094545
# ----
#   Ска
# Нря жда лоещакул, сссяши тлеть ту мдной по, дрость умалим зналнит пуспенки б сткол хре врилоо, бикдать херираль туэраю,
# Но зраныла!
# Ды удым величо!ь ь сереррали ж рчалиноюм слимако
# И ве;мци, драт
# ----
# iter 7200, loss: 108.527972
# ----
#   Скеей молий»
# — нлою, быГотак хголизы в нтстим
# У бовыри такина, росмыли,
# И вак отули
# Ив квтао праньлек тожий
# ! пожилилод бад бокано зоммнузлизыгой макна жи.
# И ва храш режарудау иралясь вы, оне  сетдей
# ----
# iter 7300, loss: 107.944987
# ----
#   Сню.
# Не налне бые немали не дяли спогетят лы налань момедать госречпо туки тримой
# Де,
# И зомим ттре трешо?
# Всегой:,
# Сла прымну трамшуща, моюд налы  слобеща руно полало коэтателим
# И нерали:
# Момеми!»
# И
# ----
# iter 7400, loss: 107.485851
# ----
#   Скалрутей
# Пероняноли?
# Ны стемуть драря:
# Можемемя племила,
# Нрагди омдохницози бовекии
#
# И до учи сж лыловрем пемеся вашя то роковакат,
# И лесеная,
# Во: паф ражемам
# И домигустий — ремвеэсьини ыли счи,
# Вол
# ----
# iter 7500, loss: 106.954900
# ----
#   Скдя,
# Еож сь пая подчи — назкать.
# Визы сеаки бралеки, бочее вемены умия збвеляцым ко кудур пбокиреле слячь ртротеми,
#  такаря!
# Пслудан Мы б доськасо нилявы, толигож увенали всткань зо вие сскан станя,
# ----
# iter 7600, loss: 106.481251
# ----
#   Скай гострань в бумати,
# Мотсйижули,
# Потомизубятьтим ло: вран калы,
# Ккит то пал сени,
# В воли бой…
# Что утжат.
# Поторнашы
# Заять долусгыл се сйчать.
# УВы бые бовищеара,
# Катк,,
# Потеракцой марющь бола порамо
# ----
# iter 7700, loss: 105.965645
# ----
#   Скаби-тВо всчна зашлиньи е на кою!,
# Налил, катех —
# Ва деть нешсстамя к в пу трея скра тох да о й пораны бутети?
# И жаль нергу:
# жить смедерятей — всешке
# тро— кал немы
# Кта велерыдей —
# Кхваля:
# И внлаш ф
# ----
# iter 7800, loss: 105.592660
# ----
#   СьнПуражинсешк нати мошемновартули щалипань стлинь помми,
# литись.ь.
# Ны натому
# Мовеспарея —
# Сдв нали тея
# И ватк на сскиви бсжак ная ую!
# И ды мучат ручий катрумрут,.
# Полько вакин»
# НачилитНсто мошлись в
# ----
# iter 7900, loss: 105.205716
# ----
#   Свашни укусуг Бычь раква мслота? олятил ны — пмботе тыли:
# «досты о дань б салие, в лаша котары,
# И лимЕи вражки,
# Натрать
# Исве,
# «Пспиныг на нверяЧти, бобикый ло чво нолята, бцуе мемдан,
# Зами жрат бытил
# ----
# iter 8000, loss: 104.771301
# ----
#   Сь боеднось Момед сслидае реде,
# И мгдишеналеть бы той,
# И талина
# Зинилив волем ливездая  сват на лоо, баниро
# Бырнодехуш рако тарнугист мтол.
# Дуг…
# Двсчи!
# И де сюди бымоссска,
#
# Пранани?
# Пранык : Детит
# И
# ----
# iter 8100, loss: 104.306431
# ----
#   Скал ра— сюй.
# И сся вомя!
# Н подяг двнаж дамя:
# В бутыт,
# ПомхялиБы ра гомтисковылоры?
# И са нанон умий
# Пот лушашетел.
# Муследи кдоемак нашсыл, ткати зарехтимцослосечи илна тращар нет.
# Свсоми.
# Улось лираж
# ----
# iter 8200, loss: 104.046066
# ----
#   Скалий»
# И ят на вола,
# Исюкв виз—
# Кеслатиф лемрлочади го;
# Чкиныли,
# Чтримесгой
# Чта ка!,
# Нвал утрани лотану.
# Зван гони лила смя тара, геща лупылу торей
# Мовалы.
# Мыстемо,
# БоРамило квеня куеть бцотил гочде
# ----
# iter 8300, loss: 103.531252
# ----
#   Скань…
# На тсришя дрненемизть от крась мулит вечка кочиж…
# Кди улив дро-тим дыробых сстрою:
# Невы, ный,
# Зустел!:
# Сжень мо жвали илы им,дих а ротжен гомем омвдинцум пастафребатьсь эра? помаг броя верель
# ----
# iter 8400, loss: 103.182487
# ----
#   Скалали?
# Ктой беемак тали
# Граранат,и
# И о дой…
# Кыми,
# Тоачи,
# И стреождь были заимцух в ву туражь станы,
# И дртеть стали-ке,
# Зати ж гра;
# Чтуришсь лилылив фетамцося буерром ссвемя!
# Мы зе внал сйден
# И звел
# ----
# iter 8500, loss: 102.743692
# ----
#   Скла босдитули беращерища, канай,щ свая!
# Талиетркнцыля,
# До, туль бмаши бочах гиот кам Ботю!
# Чростиля оят у стко жалу,к нади,
# Во вулить смпл булиль.
# Вочтось вной!
# ИзТолнае кве нашеме ротя,
# м до ттит с
# ----
# iter 8600, loss: 102.308900
# ----
#   Ска
# лиедрань Мыщте сжта ть регдуи трогов, воли,
# Ферну, умат пымосьсь.
# Пллог болинывь оларины, коловыли
# Ндренцозуд ероминыль воамые,
# Мостпустиги: реди рвули!»ьь смшль гудалкиныш нали,
# бодакее молюний
# ----
# iter 8700, loss: 101.900553
# ----
#   Скал огашы бальнонаи,
# Медорать омдастаятьсь ростовали?
# И лдот чим вемонам читыме,
# Дотямилятось по тан мышшнул дыл урдиетлы стать.
# Улретимсь жать иг доля бо ской хте слина сжете дрифеме.
# Чдий Дея покс
# ----
# iter 8800, loss: 101.541781
# ----
#   Скал — У в ю врнлилудил зы прум Болятиль летать ус векуни ты олдана!
# Ислих почи
# И бокинумикы.
# Ня зугом леие, шекратат.
# Чтот дикы ы — отажили,
# Всаной!..
# Ппо, ке вот мути:
# моный чыте Дазя жали,
# боа лир
# ----
# iter 8900, loss: 101.097361
# ----
#   Скасцозимако,
# Бомая кот водани быки:
# в той быкнижы
# —:
# Несдгн, зы стетя,
# Мо ечань в коворизуКий дато ковнат кались лилилыю,и
# Нит лылий Ботами
# И жной…
# Во до нехан велесть унекариль ить стриым
# Оща сенин
# ----
# iter 9000, loss: 100.743547
# ----
#   Скаа канай!.
# Исвит нек хуё Рожати?
# Ув мако етруней,
# ДИ утили,
# Немде бочит.
# И слоптустуми
# Зарый!ь.
# Чсручя:
# Ктурья,
# Кя сюви,
#  лобянить на ны,
# Фря,,
# Мослда нера,
# Не удрну, псстяль данали бой.
# Пухоть тыл
# ----
# iter 9100, loss: 100.394000
# ----
#   С зване оги- Мрожа!
# Пемрной:
# Урокита скви во нага тртыля:
# Естот темшень.
# Фжаныриме осди бомде родемыли
# И лескат вошки
# Готрыми
# «Дат кой далки,
# Ввой ся,
# Нрежыо хваелинь,
# И вкена больлосдисть,
# Слайа!ь
# П
# ----
# iter 9200, loss: 99.937128
# ----
#   Скан.
# Псрогдузи жедесь по те страчиК ятя.
# До сдреныйдь Смело:
# Чсе лако,
# бита я за выты щупил.
# За ччилысрочи пело, вея, по димеж логоди, век тужам вне, де тдена, о двени!
# Прой:
# На сжемать — коть бым я
# ----
# iter 9300, loss: 99.485846
# ----
#   Скал нащки немрою
# И вотци феризКапи,
# !!»
# Н стети хваг ло за в смашахры.
# Чстит.
# Тотрпуля бой бой бокваквы,
# Скдот Мым зоменый Рыку, болятир котычи:
# «Чборзцитоспвцур поюдь нарну, лудата!
# Помедно точи:
# Н
# ----
# iter 9400, loss: 99.021518
# ----
#   Склимы?
# Сжирручиа
# Бычта осыь — вдет.
# Псферащак нать…
# Н на торемунакины —теми,
# Не на толить варил,нь чоликуму зе двнель,
# Де, колитыры
# Смыл, — емна тон.
# Зать котовы!
# Нуни зугиза рылие,
# Чя музамрдаг нне
# ----
# iter 9500, loss: 98.611182
# ----
#   Ска!
# Кдраять рмобигвутся дак не виль хырил стачить, кросьтой Моед сстали —
# Ктрекге верегденять…
# Понетили — брамя:
# Вотеры.
# Зетоля:
# срулой ячилвси.
# Улох«далкие ботимы.
# Усрачал мы бий ддамкатвь ом дрещу
# ----
# iter 9600, loss: 98.181611
# ----
#   Скет.
# Тытаринь нелда — наля.
# Зари?
# На не решдаго
# И датам ховасяшбок долке,
# Вро де зотае быя,
# Фесе теж зпогах рамносии кроя верена!,
# Да, тешже нудер—
# Ктатьлись уратрлидв ладит,
# Биважнуй,
# Нруне почфая
# ----
# iter 9700, loss: 97.904888
# ----
#   Скелих,
# Кумрнумишь са шы по дочилив д ромогожая Две тем-та, нею;
# И зе выле —ьль у, поя демчнавулчам ожестк.
# Плны,
# Зесеть.
# Бым тоти?и!
# Поготаридурил!и
# Ддреш выри,
# Влпысста,
# Но, ны дыята, кив ся верныт
# ----
# iter 9800, loss: 97.652609
# ----
#   Скали бьвсой бцйМоя болесет лота цожшкать зыля…и
# Срашрея:
# Нетовыж бый!.и
# Клевелраули,
# Да, мведрной да вррне ятосеч тумета, палке — палю
# Ну врелносовь,
# ве стац хузад путром,ш сашканцусстей Носвами Вот
# ----
# iter 9900, loss: 97.299717
# ----
#   Сквулко,
# И секи?
# И уме ераним жнаты
# Поа палитыь зую!!ь.
# И вешля быв зегое вра!
# Сте т сие бореми…
# У бою сте згдуре тспи погдинь квены.
# Нырудь,
# «Чурере,
# Керажеля…
# Кам хал була!»
# Чулим
# Онлибой дорули ро
# ----
# iter 10000, loss: 97.032826
# ----
#   СкаИ скотащу нами
# И стакин,
# Дрой боМолато,
# Де былие велим ловая, хостети?
# Завочнки врамя порнутстил охвы канал ся?
# Но тя знедимы!
# Потомять, вы се нешк на збитодал хветул той были:
# Несркучи!
# Сто течим
# ----
# iter 10100, loss: 96.785769
# ----
#   Скущата коли
# У шерегву,тои кени,
# Кой.
# …
# Нвват ражы!
# Френени
# Товдата,
# Ка бомезы котибы,и
# И вакку шешемимь хатае!
# Чалпуми!,
# Ое нашшна, вещаяцолие медо пы? неть,
#  в урали жашя:
# Не трамта?
# И руланцуМы то
# ----
# iter 10200, loss: 96.512951
# ----
#   СкоПдинимыь доне-кея?
# М сналисль, роськы вамих,
# Да!ы!—
# Кка омая мротлогвость лохвюно, Да срания дотамы хе ти те лырыли зерещюно мновея квани,
# Да стошккомам Болданайцо. Бомеде качи, не ня св куевснати
# ----
# iter 10300, loss: 96.309904
# ----
#   Скашсхвать!!»
# Сжат бой тел хуя шлятим вошитим,
# Чугалки бданныв — нне ушль звеней!
# Пмненум бочназумул хой бек ни мдно кдо мтуми
# — продедаб ед.
# Ною были
# И лдвнусь ужра! —
# Умо тсвеяти лег потолРуми лее
# ----
# iter 10400, loss: 96.052201
# ----
#   Скажил,
# НуБось! бвощан юд ошрной Чисрваля,
# И до Божеки,
# Рег-псрумво тедок вой.
# Уры: рыдий!.
# Мумнди ждитул,,
# Погва режазерыл свенци В полясуси зыли,
# Ктернутеря:
# ротятолы Дая
# Псполеть…
# Ве прола ротоя д
# ----
# iter 10500, loss: 95.840673
# ----
#   Скежееть!,
# И стерна, халиь бещ счиль боСчик, вслчем поседит
# Мотой бый боБыш вескак мажаба,
# Веят,л секитцуссхварам слугоЧтим Мыли бюмый пик внали не вале накссталы,
# И Бы нвало таний
# Понуюдь ранивуслим
# ----
# iter 10600, loss: 95.616745
# ----
#   Скалег —
# На вед б вою;
# — на сьдань,
# Вы:
# Френой сседнеми
# Во валя,
# Тостя слебие комедет чалы,
# И юди ждне —
# рашох валлие вежнай!ь.
# Поснот дину боведелатьм, омвныло,
# Ивея!
# Мотомочыту нушет.
# Ульволь воть
# ----
# iter 10700, loss: 95.382086
# ----
#   Скгимулой га жерна сакани жаль нейюЗа,
# Во цдосткий —к лимаш выже,
# Ве вероюдо,
# БыДе нетка, коввну, бынимый
# Кочатури:
# Нералим,
#  пе:
# ё вална сеть хдоета?,ь ать.
# Ну лромимы нтал я ждо тернуя бой вдемил в
# ----
# iter 10800, loss: 95.192008
# ----
#   Скесь дстелятьНу стемим
# Фвены
# Зат лна, каврне терневия бьдануп скядав на посттой быми,
# Во… — сжачиталь неча, потречи.
# Плостилы —
# Кме ква трной вемчаль неча, кона той дерома,
# МБосвыки
#
# Нитены,
# И лалил
# ----
# iter 10900, loss: 94.784178
# ----
#   С воля
# мродафет.
# Чтой —
# Ккины.
# Ппо модинем стахуки,
# Ве том косщалосчищсстая икве лолвасяту почара
# Чтимы!
# Чулий
# Помощай маким кветрятычал ибый,
# З гым литыл, сератый!
# Чуя в отонаш квнак просгаф мались
# ----
# iter 11000, loss: 94.536688
# ----
#   Скамис»
# Бым бомить вз—, свао яты сдакк ный
# » Дег зекное квобий:
# Прернуя лупя сконой йслиза сташя скренисважы?
# меди сжефомы
# О, бцосцы слеги,,
# Ктерым бочкотая пратрБиными Наг промячиРо.
# Дал зцупифака!
#
# ----
# iter 11100, loss: 94.557536
# ----
#   Скамит.
# Да — слки врым оскват бо?Пох поле жемьснами болкаи — Смращали мад удруга!
# Позалень Да!й.
# Но чдалтой..
# На о дана!…
# Порачи!
# Мырхдародь буски котели модой!»
# Слиза рула б быль тозылохад рыот етрн
# ----
# iter 11200, loss: 94.229520
# ----
#   Сбашнал вил жезцут трогдое гссчий Да ятотеятВель,
# И мговела тыл, квумат ссвалое болаты незбый,
# Кда хсваши
# Мог дыро,
# в тота, войЧуе и вратьлита у вонь до мшилтола, латозцуя далиль балие Бомден уешкте
# ----
# iter 11300, loss: 93.906716
# ----
#  ,
#  дража? — ке уне дрчань бовссй—
# Кзашнели
# Готретыл,,ы
# Мые были боято сткимнули бватеми:
# Вваг е свеазРылоскиЗа скват нуми,
# И дрнеть ят потраг кужал пекной бы мулит, озжерой..
# Усгвнал колима, кеди ят м
# ----
# iter 11400, loss: 93.642511
# ----
#   Ски
# Плудай…
# Фраля:
# И ене боеди намих — намшко, керауля,
# Вдверы,
# Говатей
# Да ратесте,
# Свать-ка!емы
# И шемутес ся пожна срогис векенал.
# Псвы.
# Чуло,
# Ве сё жал рылить,
# Деду!
# И делит сспимы?
#  модьинь у квуг
# ----
# iter 11500, loss: 93.384215
# ----
#   Скднуми,
# Псвете тетьлы,
# И лереюди?
# Сдата,:
# Де болебуел хура мумумх куссркотимы,
# Как родотракихсь умрди Дееррйсь дырнаты,
# Во спиш огвал счакь лане в плов ди вд не рыдечала,
# Мозевутяя
# Помоя,
# Не, дербто
# ----
# iter 11600, loss: 93.150550
# ----
#   Скани мучие ше бы?ть.
# Нешс.
# Плохедий бы тым сьраньйий Фгехи, ковалинь ссради накия дажини пскосьна козивож
# Сторачи!
# Да са быпели, годрелех нашкаб ждло
#
# Рынь осва, паро гоещиз — те чулик,,
# И зкотои,
# Н
# ----
# iter 11700, loss: 92.876811
# ----
#   Скеми жыл тое вед станиф лары, весь Мы ватах хасивий.:
# Илать оч да наще сятсли,
# Дедочка? —
# Уж нол сваваля…
# Кдачам уки,
# Исьдатаку.
# Пюл здалдат.
# Но чда м жылись прумат ларучь…
# Свара,
# Кеть ты,
# И сдеяту
# ----
# iter 11800, loss: 92.663057
# ----
#   Схсин
# Нунь ве нол дану!
# ЧумихТовяТоте огдут.
# И, вонсивали, пролать…
# Во, котены.
# П гогото, довамие,
# И вевое кветале
# Тотдафнаг — латтож…
# У хвранивь то тиезы!н.ь
# Забугил, тате — годлосват я дламитх наст
# ----
# iter 11900, loss: 92.403887
# ----
#   Скаля: болой.
# Мыж, вогтой,
# Квой быссь Боста Бовой!
# И дамушки Врагы тременыжь Сквена пенисц,, рое варани помолися,
# Не бостиныке,
# Нерожи сквет.
# Даг вудал вена хогадил на? — не дажериля,
# Несь борая:
# Ни
# ----
# iter 12000, loss: 92.295212
# ----
#   Сятируль,
# Свдорудах чимили,
# чароза долить ботажи сё дож»
# Заущат лом воль.
# Нем протлитыли Клдинащ стгозы бодьрулшых ситий,
# Зварчналшы боетя голевы кне зоскваный
# Мы были тррулись стечкиливащи босхваляч
# ----
# iter 12100, loss: 92.046384
# ----
#   Скещил толи!ы
# У выли:
# ёей,
# Ве болесьЕсь зе слвамаять накисжь,
# Зак ны,
# Вы, бутимы.
# Поты, неш лути мрыл былись,сО дрнужь…
# Фналди,
# И пали,
# Тнались дыне,
# Дабо.
# Праб не точи сь дорума,
# Борылус,.
# Псме бого
# ----
# iter 12200, loss: 91.821994
# ----
#   Скани,
# В нелкат тусьжали:
# «Реты были трботыпнули срашки,
# Ва велерцу Богва
# Божечар ты посва слвны олдых,
# На, сваг тади,
# В ной!
# Мыливи,
# Кан конь, дашна,
# Ката.
# Помедь ковея…
# Но вечить,
# Вы слаля, дерау?:
# ----
# iter 12300, loss: 91.767952
# ----
#   Ска
# фень стань.
# Чулили, Бсетки,
# ГНе пдеркну жю, редимы.
# Нс той быя стплке мыры факи:
# Вдашары,
# Как к в зта спут.
# Тогодали:
# Быляз» сткоемие бте темны, в,, ке вреть оИ терущешшне зышимыль,
# И лешешени,
# Н
# ----
# iter 12400, loss: 91.666343
# ----
#   Скущиля,
# И на дран стейцуй бесди.
# Помалий
# ФриЧ…
# Все пола:
# хватрилы ытьй-.
# Плисчиз свана,
# Слисьсьраля,
# И в лваю!
# Дать зоримим,
# Врсюй!
# И д полкалы хвалкуна воли:
# Нашне выя,
# Не тули,
# Роветь.
# Псромцут та
# ----
# iter 12500, loss: 91.418649
# ----
#   Скани:
# Спым, не полал пемре гозамь Тогдар т бодесцуетамы,
# И деюд,д Застуля,
# Морны;з—
# Тотаный…
# Пяж коте, Даромныли, омрелох ливаши осуя ж.
# И побымитц пулка —
# Фвет.
# И, коскана бекинь в лов пинусиз
# Нбуз
# ----
# iter 12600, loss: 91.065596
# ----
#   Сцаш бы?и
# И воля,
# Не дротим жебилильсь, мод мучем бусимоля ь ловиМ люслва то мостил, Ку кит могю.
# Прунай.
# Был,, болидажемуте!
# Пру кдерани лема,
# И дне остий
# Ном зы верю,
# И веррети:
# ВрвиБ
# Срость нивы
# З
# ----
# iter 12700, loss: 90.847173
# ----
#   Скане ччийГолие боли ворныВь быя,
# Можемура,
# В ныль ттея посчий бет.
# Зе не лое выли
# И шлоскешин —
# И калумал прашлюй!ей
# Но жди,?
# Сликов бок до — ворниМы огак зут..
# Пливеляя,
# лваркии
# Пслиские пель тарум
# ----
# iter 12800, loss: 90.674889
# ----
#   Ска, ходулиуть стил, накнотось,
# Фнань виля К денарим — погдены
# И не птомла — палая в щаны,
# Во свалке:
# «Чтой дорчи обыс инЧуеща каль сгалуи:
# Чте днуда, путат ны вары.
# Плостес
# полятосил выю онаний…
# Но
# ----
# iter 12900, loss: 90.366821
# ----
#   С в» не воль Зат.
# Пулисматый, Бымнуедь имаше:
# Нашоля, пылиры,
# Норать тостпело,
# Ччары батцул тылу,
# Тогяд о доемеры
# Чфенупай болина! —
# Кте ветой бый.ь
# Наршнусть, мочта!
# Уситали геро ледемужь умрпемыха
# ----
# iter 13000, loss: 90.251356
# ----
#   Скел худина пыя мышил несь.и
# И  выл, хча омишул сяле — на сьрусрая варретя.
# Френь нызцо м потретяты конали мана стуетили ьше трань на,
# Тталко сваля росвал на сремя зы не болки?и мик, кварумь те зимне
# ----
# iter 13100, loss: 90.000926
# ----
#   Скю!
# Чту умтны Бостены.
# Псурабы?
# Тордируги: моклов на шомя:
# Нунар был тали,
# Урвою;
# Влиу дрзичел выля о дили кврода не сстеля,
# Нор,л туга!
# Сверо,
# Даецу.
# Да, де ранески зашка батя…
# Д мрнезирапи
# Нас жал
# ----
# iter 13200, loss: 89.622805
# ----
#   СкажитоЗали б свелцутой боё Потретый!
# Мосвиля босичь.
# Не трдуче вена хвемки заля:
# Бышноашкой паля маш тотяще ля,, ссет лосткиныви твой,
# Да, куражесилкеенцос им сной.
# Ним коста оскихвали,
# В, туш ляПос
# ----
# iter 13300, loss: 89.207953
# ----
#   Скещь мов ятшонены.
# Чупин бы!
# Моледой»
# И на ссвалкотури
# Тоденря,
# Вовдемали,
# РойПов лязы тдена, перчнай Боча ра — не вылать крымн.
# Нсс вретя,,
# Да, ссвали,
# Погаболятули?
# Дедать итко дула,
# Рот стастой
# П
# ----
# iter 13400, loss: 88.928537
# ----
#   Скалий:
# Нуж-лиу лосять керчи:
# «Мовдафк отя до читымя — в статны куста стащремули меятил тоетортуи,
# Во потех да вила!
# Чтырим
# О педарраги
# Тлогосквалии
# И дораге,
# В п ра онашну имло,
# Чтрой.
# Дя тототя.
# Но
# ----
# iter 13500, loss: 88.759879
# ----
#   Сцю
# Не грозбали,
# И в лыху сскоу в отат на толя:
# Наж туж бомтощи сскомезбоста илли за прденешкие
# Пое дреща, ожЧя зо дово
# Чжася ботеда, Бонали,
# Драй:
# Ктроч,
# Смы уссРатил…
# Да свенцум мбобыя шак омвюя… м
# ----
# iter 13600, loss: 88.627683
# ----
#   Скани,
# Слко дола, прешсели.
# Плутал…
# Прой Дарей — кевеня.
# Но точкчать некира!
# Чуашка,
# И даик!ный юдь жетой-ла, гота  га в зда — нед — будине,
# Ве почам бсжель татисжа
# Поналепо,
# Ва верыми
# Гореданцов ну
# ----
# iter 13700, loss: 88.306195
# ----
#   Ска
# Погне сгропочемул?й…
# Пжог босвали-кь сдим Богочый были ке дрна стемих Гоначеще,
# Премдау пруна, налана беетряты.
# Дятуе пгомнвий Чтакран, прены тучисПкие болесвеленцул скобаны
# И бслипыляож в слашыл
# ----
# iter 13800, loss: 88.027816
# ----
#   Скани квуть моз—
# Ка в зва ергула гоят зетячил в доля Да в дарый
# Мы лан быя ди мжне прум бгов лак срюсретуя быти зговспжела,
# Ройся конея мврулитыле…
# Дал сслий бы?
# Все хутый
# Сралир слимали —
# ремачи,
#
# Ф
# ----
# iter 13900, loss: 87.715174
# ----
#   Скащерань мы бие трок тозымичь быкинуй..
# Но зне свая палать…
# Двагулинед пе огвдер стали тали ква,ь верень стручими:
# Да, мете фрхита, не дьла бымил,
# ДоМ заркенть.
# Д романой Мы здут мфки стки мотимин
# С
# ----
# iter 14000, loss: 87.425795
# ----
#   Скалсять уч лке зы почи в Бы нгваш слид омшк на в пом декна шешшны?
# «Чуя им дырымы,
# И рзой-кали :гоща всчарцо торам Бомнашки бдерная дамрнае не в провде-к, седь мтушку.
# Чутил уманой;
# Ктоски,
# В брать.
# ----
# iter 14100, loss: 87.205320
# ----
#   С гвурались докнецулотосчинь зареслимунесь.
# На! всето.
# Ве сстал.
# И севденали хвала,
# И потой Мытулитылось:
# Исчемат ту стелатуры.
# Пю…жи
# На ста,
# И тетолитьлуОсУ дрике!
# И ды котьча.»
# И рове модк не бонци
# ----
# iter 14200, loss: 87.019180
# ----
#   Скаш на сер—
# Исквата,
# Мы сющавин,
# Куматрчий
# Да,
# Чоссвали Слясук мабонссь врелцуаж скарцыта бый Матрать.
# Помне в зна сгесмашя:
# Нештоллятомы ме вроща ссте!
# Чуа, огваст.
# Ом оссьшо пышось до лапут.
# И кат
# ----
# iter 14300, loss: 86.838661
# ----
#   Скла брамий дышкал быж — — неящиль — не боляты ж див коли сжден мслималя бясмагчи та тойзь встен ужалны у гена сте,и — мотоя — Сетих были,
# Чтирни швнилиц до киоть ите — — неких,ь Слкуто, помлки гедру
# ----
# iter 14400, loss: 86.579290
# ----
#   Срезя зиски мопяю, падвной.
# Пжернешь проспемнам былы.
# Мы в на ты недисть имемы.
# Пспачил сван ячил та понцоские слпант на богашо, наля,
# Не пулиБы хвкуе бы?щашиние сстки маю, оть! пе зедремул.
# И вдат м
# ----
# iter 14500, loss: 86.344431
# ----
#   СкаУ сГядвграни мугкалви Божашее пумжамь — бала вала!
# Полох бола проног доли,
# Дырачь на, —
# И лерной бомки точное трам бобудераляшТнашат Мылы ха престьки —
# И секвотули сленыл ськин!.
# И волюв бути ны в
# ----
# iter 14600, loss: 86.136212
# ----
#   Скелин
# мвы!
# Чты кугозС меняПолие, кренашы нашинь сремечем йцуза в муто,
# И довели трануда?
# Мы, бычи:
# «данали Бы готали коч ды трусеменечи:
# Босмана, ь межень.
# И вакихаши были:
# Фрегимуцусь дой…
# Во, пему
# ----
# iter 14700, loss: 86.060112
# ----
#   Скат хучи Ночи
# Прмутота,
# Врать.
# Чстнаш ремамитцужик ный.,
# Не,
# Бордеко,
# Зит были вале:
# Дданай.
# Ускань я бивтя,
# Есга, верог нылитьс илкио все дося:
# Нешменьи
# И внвеним
# В, дременый
# Рым, ёскномзинид вешно
# ----
# iter 14800, loss: 85.950162
# ----
#   Снень гоза ларать та пло ма ссмашя торну, освя зал страд-ка устали кполать.
# сцау в продв та встраля толя:
# Ктуе стетали,
# Мо в спрали:
# Ве годноспимы
# — всляча, то теерееля:
# Нре мвг: не доли:
# Некнувоять
# ----
# iter 14900, loss: 85.727253
# ----
#   Сталы:
# Слыл  быля ж тота почи,
# И озгтог зе болиы — не в Муто логощукина Муный!.
# Псито, Слый
# Плна бхупь,
# Ввалкрытый.
# Мылу стетинь отретея:
# Ным бцутонь,
# Тотарашки:
# Мосмая
# Фрале!
# Чть телеле,
# О, худо,
# Ва
# ----
# iter 15000, loss: 85.451622
# ----
#   Стейцис былохта мы трлы?вь сь дой…
# Воты тя дак на волем пте колав зготол пужал откй хвазамугы
# Все боляти лаши Босьвими — бодатат.
# Плутам нешзессьвал ыть на чой
# были ы коках дато,?
# Пралм нумих дабыт,
# ----
# iter 15100, loss: 85.184175
# ----
#   Ска—
# Уроге емвог Слою, ветрелки бревсстаринуй госта срездане бой бий
# Слыку вати,
# И вылук балисмиле хафкк буми,
# Слипулие, яст вы? веды,
# Сскек нак отМил.
# Поный!
# Иссмит раше хся прлогдак е в гата смырим
# ----
# iter 15200, loss: 84.964222
# ----
#   Ска,и
# Пот чам нушки бсё лупамо,
# О смчисвь пулой»
# Чурим дет наш леналеераляь ю! ветрять тредула,
# Фрныле бия улань,
# «Пура жалы МГсдарнусть ной.
# У мюдь ять в не врной бы кудал ожалуе мали — ресразисьрит
# ----
# iter 15300, loss: 84.935007
# ----
#   Скаши,
# Чуя гатраляжь оттал сты!
# Умосте бостича храм свиа всралки недесмнись оссвалит,на?
# И ди то лячас вый —
# ляойдок не бобили  геда? дрой:
# И жалтог омлда ссти,
# Чтой…
# Де затьрали — пранцуз, думи — Бо
# ----
# iter 15400, loss: 84.725240
# ----
#   Скалы!
# Что коваки бапилетыл были бохики?»
# Слих даши? Скоерцузтой.
# Де заре будат тумисДе сжеки,
# И Смы гтой…
# Зва прумна ссМижало,
# Помы стат.
# Ус гогда сродик бы?у
# Франие нединусв лиМы п лиегдал сь выли
# ----
# iter 15500, loss: 84.557965
# ----
#   Скени…
# Дв усть…
# и?, осюди жтрат рымь, Бымне бодинал выли те вылу несцой сцаш слапил, ерддралной д родвалки не нотя
# Потегяще стат.
# Прулча,
# Рамуй…
# Фрная,
# Ни за былосесь,?
# В, в ереготь утли,
# Да! пражи с
# ----
# iter 15600, loss: 84.372254
# ----
#   СкенисТковея ковний
# Прертутя бы Болечал, кверуль хва на стьля трезення…
# Да стемн.
# Да бгама б зарием бцу пал габоские,
# Нерат болае прой:
# Немны юж оеры вылив ву кохву коверяя на сьшеть.
# Бырымы зебиелдь
# ----
# iter 15700, loss: 84.170724
# ----
#   Скещи мжие бостащушк намаять нешк небилусь;.
# Пиусдаетьки — ке бомали Слиемну.
# Фрамы?
# И биваля,
# Ввы угоди?
# И дедрналя згвалы тами.
# Поп чее дыли неяда, я госта луим Былосчим пашы бГосквена,
# Да, пало кд
# ----
# iter 15800, loss: 84.158212
# ----
#   Скани и нали :ллих доки,
# Урогдол ут..
# Де жашинне бонашинь д поть ремить ськоськие почреля дорумь,
# И довея пата, кведана,
# Катралу намий
# Пуребыя вкреты.
# !
# И ядо смготлоташи бреди.
# Мылу ник — сжбинраш п
# ----
# iter 15900, loss: 83.950395
# ----
#   Ски
# Нотум бупыли, Бверол.
# Поости.
# Позак в помаля:!»
# И жаш оре: ушк хути тышкой,
# Настех сту.
# илостей
# Ктрернае — кутай —
# «Пулгоны уся ескратий
# дак налдиты
# Товд бамыл та тостил, немиля: некы,
# И ролако н
# ----
# iter 16000, loss: 83.663648
# ----
#   Стекина спортусь го во емаруть мередь мры? вар нгукосьми трусгаризупрели:
# Ве вдерог, учита,
# Дг, боквенку им шоц по гото коя воля:
# Немин лизвасть…
# Робудоря:
# Бочной стил? беюди утань —
# Улыись косчвил,
# ----
# iter 16100, loss: 83.600391
# ----
#   Сте логит рад ся Рой бей.
# Чт в лит всять Боуми?
# Нед ствалрый —
# Смисьжалку,
# За смраты?
# И, кана вин
# Мы тесгал сяж
# И во кват свой
# Пуланы был, —
# Нань ды тоден,
# Мусканцышя мамика!
# Чту кулутосшлив зчо я не
# ----
# iter 16200, loss: 83.319167
# ----
#   С ти жа таскам.?
# И миук,!»
# И се времустажьлну зодрата, квая,
# Да вречь моздакинтой кы бсечим лцучий дал стамна,
# Рре донцас в сминым:шнемийц,ли — бозашиеть оскванцу жне нотшмыл тол залнтым,ь ны гоза с
# ----
# iter 16300, loss: 83.153491
# ----
#   Ская жастал, Кугат!
# Пломаби шуш в мнади косяты касати.
# И вдаромцц были тая по стох пумами?
# И ятом зы емедерая лам буний
# Плины?
# Моверено
# Зак утари?
# И нали масячал тли ледал трая:я лароги
# Промеячи.
# Пло
# ----
# iter 16400, loss: 82.958773
# ----
#   СкоЧ стмна, се потины днекила редко тамие татенцс Мотлпочнапи?
# Товетара,
# Ктеменцуз,
# Чвалячь!!»
# Слисьвинь де роза роди-кан бодиета,
# Вв болисвал немы
# О сроМыл в лихувы.
# Зий посскис пуели
# И дихрамя:
# Бог
# ----
# iter 16500, loss: 82.738316
# ----
#   Сканы тоз— кав нта хвдая Ротущойцолуме ячил: кипутрс пулку…
# Пождае гескрати,
# Чтой лцашут х терол.
# Тогвать умоко
# Засьралу хвать…
# Зачал тале — — Ретуя бГолив ссквот нитоти?
# Смаунь свых ворел.
# Былител н
# ----
# iter 16600, loss: 82.707830
# ----
#   Скалуь — — боная говвой…
# Вж д пожьй врзлумичи
# Не ом дою!
# Мосрваляд,
# И в газа кве: креумый
# Мы, жеть.
# Пугосдито кутып,
# Сла стетя
# Исварала тейщля…
# В дут:,
# И рыди налит.
# Плихуди,
# «Помыны вая но толимы ст
# ----
# iter 16700, loss: 82.510696
# ----
#   Скак нал!
# Потымя:, кви ще ботали,
# ! бта исмича!
# Плана бые, Бырам емы тедай быжс.
# И ты стол!
# Тасебтомил о ямж л.
# Не нали,
# Тамы:,
# Да, мторнусспаськана,
# Дау на готрут..
# Плумеги
# Нралих стемкина были бсюд
# ----
# iter 16800, loss: 82.400746
# ----
#   Скещащаки,
# Сромна шотя,
# Но омютиныли налшо, ка гото толучаг болцизо кво воеть поданы гостмесмичёсь с жил, утраты —
# И — покнат.
# Слние кохащати коетшемдну.
# Тотячил рылие воть умабучаэ буйцос кенатех ну
# ----
# iter 16900, loss: 82.190154
# ----
#   Сканимлу тами:
# В егрой дикуста хвали теень нечи
# Нату пыж ны.
# И нашил:…
# Двы хыроз
# Воеть.
# йцупро…
# Дерымиляшылы были жилд ускваля д волки кохаетьськать — немая Прогдак на кя смкенемая Прогда строгне кдн
# ----
# iter 17000, loss: 81.968771
# ----
#   Скалие бонемий
# Посгпубилтие вогазь в путномы на ся,
# Ни
# И дерезно Умог ж зобядун спумля:
# Нетою?»ь бостенул е лашеданассь лыдит
# Мы о дерал сани квнули наясП норещали
# И вддат,лои
# Ков мылироПости,
# Коедрн
# ----
# iter 17100, loss: 81.713060
# ----
#   Скебь Мокули:
# «гдо, косьюдь достат М слие пессарестали — корамил: зедать — кверем ся пожето.
# Умылем ный Былитыли
# И следий!.
# Мылу рдамте!
# Чту пурхаля — ю! торум тужалу жаминыь неш трусять на дореми,
# И
# ----
# iter 17200, loss: 81.548613
# ----
#   Скажи?
# Се вещул, как на зимныки,
# Мнус.
# Как тешныримы бибь чую!.
# Присть устьким жц!…
# И почя вря то куты.
# Му вдаражь.
# Мой водь худи лцвали
# И слив стю, гетружисВ кись зой зомя не удара? —ь ны почи: Свем
# ----
# iter 17300, loss: 81.258752
# ----
#   С бимо дерезьстать усквал мятуди крогруд смешней д пизнали беять не зы гоюди т дечи,
# Мо томло тумилоя,
# Федяя,ь неккись ны по огдакина, нерк лемугам вемя…
# Да, сгвал несь е дений
# Далыча
# Не бусга с важ
# ----
# iter 17400, loss: 81.116541
# ----
#   Скеть та бый,,
# Каску отретый:
# «Пума дрна тониМин в стечим Мылпо вогеть,
# Вугов дый законь шали тоитосчизак наш оля ле потохромы?
# И во в сершк тато.
# Во квнимы —
# И ячил б постависть ято лакой.
# Уло камеш
# ----
# iter 17500, loss: 80.894174
# ----
#   Скечисли огемул.
# Истеражень сьвилмие пжет рнудий.
# Мы политари
# Нос Мы, росдет.
# Уль вестаммен,
# Весь поля:
# Нешшнучим
# Мы скдата!
# Чтол,
# Дары:
# И вгда, ной.
# И лак ты быю, —
# рбичнь вы откенат умсштой,
# Кас в
# ----
# iter 17600, loss: 80.700751
# ----
#   Скещ митоя как утсуить либцуж бы кочисть…,
# Враш рудиры!
# Пюс врелюди
# И спвалку те вроть — — Смнсдиу стай палки,
# в ы нгдвасстам,
# Заш неМисть,
# И дрязость,!
# И вне ли врлкихузь нвари поры!
# Чя в куди тужат
# ----
# iter 17700, loss: 80.525919
# ----
#   Скени хвората, ылшя за стечь нится — Был, чалрыт…
# Зак бышое, проввка,
# Даща срасьшь насишул тениУ немепя.
# Ф ремир,
# Не прогогвос
# Мо скварамцуц…, в нтен
# Боточи!»
# Слисьтьрамцу то годь водреки?»
# И вол вал
# ----
# iter 17800, loss: 80.414689
# ----
#   Скамих срятлугы
# Не бовая пробой щашк ттебутий
# Фи
# Чтиниль ботя кил денужь,
# Вев срая:
# Зрво зныУ сьдсинуш ртатт.
# Да,
# боскали тромене,
# Чтимеми,
# Быр—
# Тотаких камя,
# Них васчим мыму.
# Де не струски, Тартой?П
# ----
# iter 17900, loss: 80.348822
# ----
#   Сканим,шкне былить — кашы тез—
# Ули веля куб дрнылу бодибуми
# И мв дол:у в оить ловели тлпож Мозав неграл гойсь сквеналцу жедох тул.
# И сю;и
# Немренге билгыту купран рят. — наметь,
# Ка срея…
# Но нтя доритО
# ----
# iter 18000, loss: 80.128178
# ----
#   Сками торума — дередь ныли,
# Ни нам быйи о гезосккие ося мо путоли вырыт—ь утаки,
# И рите пое вогнал,
# »»
# И тожал онаты.
# Тожалу.
# Звут я дая дрым?
# И далк та омносчиты малый,
# Нумкоя
# Тете прог огам лгы воз
# ----
# iter 18100, loss: 79.843305
# ----
#   Ска Бые секуся яНесы гстали варыл сельи,
# Де боела!!
# Мотодать.
# Можение в боримшнуй
# Пра ме бомеми:
# Де былысы хусь моидь то… бовану.
# Нилесь, каг муч.
# Исвал налпой боа сьварумяцВо чил сешчак нушлись, я б
# ----
# iter 18200, loss: 79.963003
# ----
#   Сканыйий!.
# Сличь дой бы?,
# И кя под на Москонарь,
# Во дялем бата, смажени зосваа хвату трнуё — негдам бутслити удо — ко де босязих ной дали мы гозашики
# И дрветять срашкех,ь наки трсхисвенаныча,
# Веве д
# ----
# iter 18300, loss: 79.801986
# ----
#   С чилосьНь трутам были
# Незалку коталя не вылись,
# Нан счишк бутой:
# Слоияшловьроять… пучтостисТой диемшна,
# Фракдой б нобилы мекана!
# Чути лтруся.
# Не жетолу канык!
# И ларыть Засрализь в боё нцушк темнойц
# ----
# iter 18400, loss: 79.765585
# ----
#   С вал руть не далка,
# Д, коучий…
# Но тесна спали —
# Реная Плеболать.
# Де биза дре дрлоб,, кракы?
# И ячгем оста тетемняты когашки?
# И не ков юй коварал ь бовили
# И врещали :сросьго с коебо в ябупызив бод ден
# ----
# iter 18500, loss: 79.682405
# ----
#   Скалцой,
# Слось в клии
# Дра доть — нечи
# Ужалесть б сичи модамаш рата, сбра,
# Свальсея п путол нат нтинибимы — даго
# И мо дарил, варгещази— лери
# «Фграмы
# Зна знерещил,
# Крак на, кетащаль,
# И лциз«даро:
# Могда
# ----
# iter 18600, loss: 79.483899
# ----
#   Скаять рмилы заренььтом оо перне — комея:
# Ную, квоя:
# Нут огои врлуфе,
# И пед нут..
# Тымог монень врехтан туля:
# росиевь сьль сста,
# Заушечги,
# В ведрну поме ся полга тссчичал цустореки,
# И знуй.
# Нось етерн
# ----
# iter 18700, loss: 79.670726
# ----
#   Скеги нале,
# И детнам былих дуражас мажи, олашферя
# Пстрлемнной замнано чиньс, —
# Восешнуй де — мы то пеши тре!
# Свенали не бою!
# Крашесьть стапь о«доря
# Фраг.
# Тотаба, Бударо: могюдь не дземены
# О буний:
# Сл
# ----
# iter 18800, loss: 79.412353
# ----
#   Ская имвдеруи,
# Урытя:
# Бы гоюди!
# Погудаш сик..
# Кь нажну, котя:
# Не меланайи.
# Товднс.
# Вот,?
# Немаксхак наш меча сьвьхать нештемязьсваля,
# верены.
# И леши?»
# И весгов лие лебыя жаля овенот.
# И, поли:
# О лаг ст
# ----
# iter 18900, loss: 79.275934
# ----
#   Скат нали Ра не до лана?
# Кавый.,
# Номе?
# И я прогось лихтя гоза врем зегвус.
# У срвуль
# И томалу,
# Зау сячарта пубуские некика,
# Кам не сская болате.
# Планами,
# Стретя поля
# Проссихвуй стакие нвемнумы,
# Слисьв
# ----
# iter 19000, loss: 79.043174
# ----
#   Сканий,
#
# Ншкотя во как не бо.
# Плойцуй болаш ере скимим ут.
# Заки.
# И лдо быйцуе чутам тут.
# И сланты и, желты
# Усяшдарнули:
# Богатой бы зат тражьшска,
# И бсе датрнал стуких, дрло.
# Пюж мобонизц смры? б поре
# ----
# iter 19100, loss: 78.909344
# ----
#   Ска—
# Камали:
# роднескки
# И чиль свак насО жтрата,
# Грлафя дукали бобьлусрат ны!
# Тоятинуть наки,
# И ледартй.
# Чт я ждинь статы:
# — боки бовить той болазый дарымь — пемоней.
# Урогдо тсвы.
# — — неки тырем,
# Чтой
# ----
# iter 19200, loss: 78.657888
# ----
#   Скали ташись в нешныке —
# рая плема,
# Румушина ся, урани!
# Пжетрун Мы той.ь
# .
# Мотюдут...
# Постой странись сык т боны,
# Воваемена, —
# И тото.
# И волка, слвня,
# В се дана бкабучи!!»
# И кутали б пролить — недьсл
# ----
# iter 19300, loss: 78.599410
# ----
#   Скал хтесяжь…
# Неструги?
# НесРети,
# Во свак Смемулосью!
# И дил ероля бак ралисть —ь потки?»
# Сверробязы ждя бовали тою? варие быя,
# Не ждном Слхвя воря.
# И нали,
# Вит устенаши та гоЧто моныи слача, сьДарыты.
# ----
# iter 19400, loss: 78.430834
# ----
#   Скажьй.
# Пэтакатцу жолитьлим ззю;цылол динильсь — слиДа,
# Молетоне — на,шь бвемцуме?
# Чту рона, смалих был, —
# Фвим?
# И коварыть вы готочилли спесиваля:
# И догя:
# «слой.ь старишу лосьПолы —
# И ечила, брамчни
# ----
# iter 19500, loss: 78.250793
# ----
#   Скажи
# И волать тостий Молала, юшосчиль на вретейнь боди торжю!
# И, быроте буларанив нылуи наши,
# Драпимы
# У, с дсячил хана,
# Молкита шерарый.
# Ным бучил в уя:
# Богаторумашквек,
# И стрелка эрашвейцулимя Сскв
# ----
# iter 19600, loss: 78.058481
# ----
#   Скажик не всломы — на вало,
# И все всё вы баты,
# Ве дрны:
# Зевшемнныя,
# Не трыменцузи те транырейы,
# И кделар нуди,
# Во вечат тат нтышуть наме.
# Постекине пылу тсвалданы — б даныа,
# Незо ресстанил.
# Да са шен
# ----
# iter 19700, loss: 77.805275
# ----
#   Скаи скееять на торяПул,в тый
# Приры? неди тари:
# Бажнал пуми бой Мылуть отошинь е Дернули три хввой дали таласьруст.
# Чти лечомая Мы нит пузсьрал: одначал раки,
# В бы, ваныка
# Пою, слак-ка боеря!!
# Мы том
# ----
# iter 19800, loss: 77.711112
# ----
#   С нью, кехвал сталя т конымы.
# Даг тыМохваля…
# ...
# ----
#   Скалми месчали —
# Врдая Роливви каквном на бунав сяшвраут тыш сары
# Заболиц, выль срего
# Насгои
# Дю, от— тоны.
# Ни тучем кута мспиж
# И дак лареш емя твучка сесь начи
# И ссмедать.
# Мы вотьй усмала нашь на ско
# ----
# iter 20800, loss: 76.354131
# ----
#   Скений цоробивырны дна остари?
# КРеде!
# «Рбуй с валя мдонали
# И дратскив бодаш трам междя:
# Бык тызи?»
# И ковал гы мы хоредин был пнут.
# — мыжна ушлие боячи тры недуи
# И Чускак сяры молаки тыма,
# Да, валу,ми
# ----
# iter 20900, loss: 76.235573
# ----
#   Скажинаже олям, ледья,
# Восцимо«Тагали на годак нам пужилие,
# Моташностил, кво жтушки,
# И яжал,:
# И вемареть — не дьк котали,
# Да
# — вой.и
# Не те зегю;
# Урдиштесь нтути,
# И вед ражьБой!.
# И нолеМы зесвемал сте
# ----
# iter 21000, loss: 76.023980
# ----
#   Скани в помден,
# «Рулив ушкераг,
# И шлеенцу сетаной
# Мым топутий!.
# И одана боДа —
# И тотил вы.
# Ввнудит.
# Да, бнли нт, томятло…
# Досцут кокика?
# Слив этак нат залый,
# Кулиры
# Путромем Москил вы ты дереньки?
# Да
# ----
# iter 21100, loss: 76.107449
# ----
#   Скеть мы зашолястал сыл,,
# Даг бовь,
# И слие ксвал лките пождной цромы ветьйО,
# Смешя:
# И вогать…
# Госюми, готсснизустем ны.
# Остал счая листе,
# ВоДа, Мо гозаной-ка ше недьь ная полкя…
# Д, веболя:Пои, пе тре
# ----
# iter 21200, loss: 75.893926
# ----
#   Скагем,?
# И дат на хылись,ь на шылосыть стем стали таг зе датралшуть той на какоать — ная:
# Ножгес моль тка?
# Не во лцолвие теженьй,
# Кы стале:
# Ечивслки кавсаки —
# Дак тры б гем румля знабимыле —
# Путей —
# ----
# iter 21300, loss: 75.909905
# ----
#   Скак хтучной ди коне.
# Мо жашка,
# И зеюдаля мрогяПов д лаш былие бядо, войПов скват яча! нашкены,
# ё былить урнеспупины!
# Постатио
# МыМо, крегдал олять нотит
# Слиемея чат худись освьря:
# Нем подой,
# Да счил,
# ----
# iter 21400, loss: 75.859970
# ----
#   Скажи,
# Такали хдарущам умы тажци, вонали бая помина слаж на дорум нам Боажен наш путрал ля, лашетьськана, огодо.
# —,
# ВоМонити ждной
# Пукой.
# Мы удкая:
# Немнег помиданая дая Рихвватрнцуи богит росдилфк ку
# ----
# iter 21500, loss: 75.596986
# ----
#   Скастас тулаты:
#
# ваши буна слешела,
# Квальсемтени пю;,
# Кте родьрать татя,
# НеИ леть несшлите пожяча  вварым букй на, класью!
# — ковсьми И детрржих, Ка стали не яжднат стащил о твыл?тув пеля,
# Вее кое выл
# ----
# iter 21600, loss: 75.401574
# ----
#   Скалусь б в дреналы тули!
# Порочиты тежили кротемизугем ? говак нте збое вали —
# росцвымл ту конишулкхы?»
# И ссквали,
# »шое боятуй были в Ботодилусь,
# Ностаж пумрамя,
# Потав не пы? гдат рутсраля элюО верро
# ----
# iter 21700, loss: 75.175526
# ----
#   Скаумне нужя о бивак отары,
# И ве воря.
# Не точнет зуя Прожнам наси ж потар болы ватруй ю!!!
# Св ратой бычи к ята не даргой:
# Ве срамил, —
# Дакг-ё бой деря не ветя,
# Да, лохцудит мила, кани фемртя ковог ко
# ----
# iter 21800, loss: 74.949161
# ----
#   Скажинь мы зго ве слара?
# — сраго кварать те вотя Слядулить вымин
# На? гдомао мвощько буень кой бой юНивту тостачамит
# Мы земи?»
# И воё ту минуй..
# Ни мы готрую!!:
# И улит були:
# «Ретсеть нами-кал туй сьват
# ----
# iter 21900, loss: 74.946381
# ----
#   Скажи-кы калина!!
# Путый Фтро.
# Да, волють ннем Были кве кфеть ужать бой беки:
# Ват ятРпучароте:
# Кра бути кробымил,тый
# Ботуки как оташ вараралить — не в Ботлдероле,
# Да, юд боки, вралих жаром
# Сяти тыли:
#
# ----
# iter 22000, loss: 74.797297
# ----
#   Скажи-ка бие датрый
# Франуу…
# Да, туги:
# Слвы бажейцосвак настел тылу на дролех пуна,
# Все — не д ормуга, Багати,
# Дасьрачь билов пем недь мтохвь в лой вент.
# И трочила сю! наш натро…
# Все рося протониМ зес
# ----
# iter 22100, loss: 74.688362
# ----
#   Скажи
# И?,
# Кустра земанись вой!
# И в вы? намним, — Даг на долдат матссва быху Модаш заляше ротойдн смлиза, ка в рожюдь…
# Всге тгрыловей палкиниль, емател плоц,тоста,
# Всежту.
# И тешлеремя не вы сьдик,
# Мос
# ----
# iter 22200, loss: 74.485867
# ----
#   Скалратали небыя
# Повеся Молашо мит утрый
# Чцосскати мыли муег: мне вулаг ту пушкеть — отути торила,ь настртоми?
# И лю, тобыви
# лдару
# Не мосчи т пом ныли ляшсдем?тынис куна быя щаких булготот Мы датя мал
# ----
# iter 22300, loss: 74.452578
# ----
#   Скагь тоги?»,
# вашнерна спапстещуя,
# м лаг дутол,,
# И домилось ине вемн нуюшулы —
# И одь ронивий бьрища в ковь ботаки
# И бвереть.
# И в я тры биетятут пуман хвверчи трочил: лещим корташл сь бонани, Слены,
# Г
# ----
# iter 22400, loss: 74.223278
# ----
#   Скнь омате шенаши,
# В угабой:
# Смтоль та мешлы
# УЧусты,
# И сквераг бзарагьсь о нешдани,
# Сренень, шо ботсю!
# Кверать на прозединя зо в позамроты —
# И лыты,
# Слы Был, в боля,в в лар нуй долшо не зулеть — как
# ----
# iter 22500, loss: 74.009996
# ----
#   Скажи мотюе вемла тыки:
# «Чудим уче,
# Ртари?
# Ва боМы коучи»
# Срие кедаять я влик,
# Заш реторчака, быМ сак не поми босью!и бав Ботя стреныв пли брогя:
# Немих кавелы,
# Вусты срая донч-кихвась ламешта,
# Дливил
# ----
# iter 22600, loss: 73.923555
# ----
#   Скний стох нетий,
# Квулруссь утомищ ут.
# Чулих, сяча, кыана були.
# На мерчния,шкени:
# Да мдатую
# Да, гоМо бой Мы тумдихть…
# Гне вешкил, хгдо тамини, кратим не били в Ботрощешизый б лыйц.
# Нслид о тры бов ди
# ----
# iter 22700, loss: 73.853039
# ----
#   Скагий Мамнот,лив болкива, ками,
# И чинов друтры.
# КралисВли вы!
# За росдени Богова рарезерная породать — мельрощал огжи тле вула, дабуны поми,
# В ерпому
# Онс.
# И стстало не сто пемог е вреть не дечи квоть
# ----
# iter 22800, loss: 73.683317
# ----
#   Скет няща!
# Срегда стыли у» нтет,
# Скоа велдали:
# Чтол ны пету мнусия тя логоти лея,
# На стебалгу болые бул..
# Земил сьжь.
# Мы удогна вели гараг птогсти злитесь санись ждеять на стомеять омю,
# Вод, ков я ве
# ----
# iter 22900, loss: 73.481520
# ----
#   Скажи.
# И в ди?
# Сме боемане сресь постачале неть,
# Врочго, кирашиль лоры!
# Чта зРестай Былиты жилой!
# Св порой.
# Д, кото мы наменей нея
# ж ророй вой.
# Пже былипо гда паражель-ка цудолк! Стритулих виля вул.
#
# ----
# iter 23000, loss: 73.345286
# ----
#   Скажин бужи.
# И немя,
# м олесьрул хучи,
# Вражил сами муссвели Тамденем сьрисхть котави?»
# Нарако табедьрны вемдку,
# И дорет..
# Москит ны пряж детн.
# Пум бопы!
# Пусквейшне бый!..
# Тотушин, пощле — ветя у верат
# ----
# iter 23100, loss: 73.194290
# ----
#   Ска—
# Куть недь осмвеля:
# Н пресгоМыздинжь.,
# лекийПуста,
# Каг отреся умиля Борддатемж
# Ни тлехали тспчи ка прзое ератил, верки —
# Мы в бупалик
# И лашесьль бя,лу хаш хрж позтой..
# Ний недя о варкан ю!
# Плань
# ----
# iter 23200, loss: 73.091136
# ----
#   Скани,
# Во жле! Спе говы туты боми-кие болать — мерны ита дромнуНизы!
# Чуд мотоя Слось.
# Зашны вемкома
# О болаг, бодаутном бой выя жали то, сча! нать.
# И не пог квдал:сет, хуй бил пушзырашь нбеда отЧто зя
# ----
# iter 23300, loss: 72.969446
# ----
#   Скалих Пуми,
# Св сьвьната,
# Наррат: лышитьсяя
# Прымы?
# И нив вот листел, крагрпустоли в Боскваля:
# ляд точчим ла старик
# Мо вовамныний — мель тажь устали:
# Тоегог, Сросстали хра динцум лещеслкут.
# И нлдых др
# ----
# iter 23400, loss: 72.953876
# ----
#   Скажистили тушкиньсали быни мы наны.
# И всым?:Сли, недьрамцу болашхурий
# Курам былисе сырилось ненаси коньмь на жая ка часкоза биливай Чтералка бычие в лпизбылу,
# Поуредьря
# Прамо,
# Вилшилоц сскалкуя б пе
# ----
# iter 23500, loss: 72.949865
# ----
#   Скажина,
# Мот зем осьвь зарие:
# Богрути ссплпочнаринулих квену.
# Пжали бовена,
# Дае дролень от почишо рединь бознибупи бдане:
# Бостами толаты —
# Ри, прого, какоуть ковены утака,
# До, вула
# И дось вы гозавиет
# ----
# iter 23600, loss: 72.978852
# ----
#   Скать ныл, —
# Нетам неши рят эрнуе былусевь.
# Да, ковыл, нусив неме худен»
# И вследая исевень отретой.
# Уласат — не вщеря
# Псетыить был е неденей
# Ктой в проб на мумнеми торымы:
# Есть я Роты.
# И нешполи те м
# ----
# iter 23700, loss: 72.848513
# ----
#   Скеть жашка,!
# Постоли тручик осстать улей
# Чя жекотси,
# Не намаши наверуя к днемил фремия
# Прамболю в в мот стренат дак ховдо…
# Да, подойра мозЧита!!
# Путе!
# Мысвали тагрестоля стронь ивализ»
# И доерна огва
# ----
# iter 23800, loss: 72.831066
# ----
#   Скалил:и зва кона и зашки,
# Ву вемеремие?
# И на сголь ед промя:
# Ночам бутерум ке хромедна б повралрым лятоНи, о дрольНнаН пудму?
# И яза юг в ордо оденьсруй билыхы бы.
# Двоещели —
# ррдабый,
# И в ё доря:
# Не
# ----
# iter 23900, loss: 72.681743
# ----
#   Скну в конас, воляча, утребуна гозусскистал были,
# НоскиМитлве,
# Дат трутя,
# Не обилась, Бые страством косьвий
# Мы на дерега,
# Рустьли, кораки:
# И водак ятИ толься воля на зцогот вотка,
#
# Мосю;
# бы, отанус…
#
# ----
# iter 24000, loss: 72.495512
# ----
#   Скатих неши?
# Куть ту полене.
# Ут дречи
# Неснень —
# Нек нашуя жесь ностии бою!
# Да вели
# И дочи,
# И ядаленыь сталих Корище шМое пореностами,
# Не не дучак бышу нари
# Вмугже толи трругит,л вала бау…
# Слисуси у р
# ----
# iter 24100, loss: 72.389895
# ----
#   Скю!
# И тох ноза в помдертуся жданал столее
# — — не буледалу мами?»
# Начнами?
# В наль роднуй.,
# И тоит.
# И неметая
# П мокова,
# Ве в ласучий
# Срето ныличали мялда! нцид нисли, недатн.
# Ньшныки,
# Ков лпо умие, ве
# ----
# iter 24200, loss: 72.134645
# ----
#   Скагь ларе Болосались посять ны бы готоли?»
# И былились ный,
# Кларташуми:
# «Рбали лемань ный!
# Свварилты.
# Не огава баг щримнену
# Не на бупан буе бугезб чис вали бую! бяды осжеМин хвлитили,
# Досый:
# Кто как
# ----
# iter 24300, loss: 72.060385
# ----
#   Скажастеля,
# Во, лаб путрамцох, веркн.ий
# Досьйа?
# Быруть были лемний билисили,
# В рередремтля:
# «Нердурало машо
# Веналки,
# Во полень,
# Нутря, котий
# Куя теми?
# И верогкиовак о»
# Но зна киноссьданак?ось позлны!
# ----
# iter 24400, loss: 71.933462
# ----
#   Скажи молявони, ВоДа
# И рдуричие пула
# И дом очим рачи мротя.
# Не ворой на!
# Что чи,
# И ны томя Програт б спакк наши бою!
# Мо та кыруты кой боля вернучи:
# «Рбучи,
# Скеаге:
# Есть ятыи?»
# И быю в лашкоедя:
# «гаго
# ----
# iter 24500, loss: 71.862433
# ----
#   Скеу той баки были были за родноста,
# Фны быя тряты мамины истем быТов вый!.
# Всть…
# Восс виля гдов улкеж.
# Звый нами,
# Вурьге!
# Чты мзатен
# Чтонь и свернись говали,
# И не котать…
# Зедоными б усмак на шупражц
# ----
# iter 24600, loss: 71.736623
# ----
#   Скажи:
# Сквой дикуя говудий цо двемаять стрена сятый зариту ра знсссть могало маши таш Болка,
# Мо, кремжеять лдань утаралости толять урдик на зи кдечкловвест.
# Уж ропртоли:
# «Потручнаж ли вола бойдь…
# Заб
# ----
# iter 24700, loss: 71.501375
# ----
#   Скажь.
# И вдонесцосили законьсь.ь цоздемнуяж.
# И товы.
# И яжРнуты — бра протою!
# Что каройцуе дресГоредья,
# Красьши тряща рашил:
# «Чбума згвашалкита фребичь дилиты,
# Канил,
# Гоё вый.
# И мскотамиля ж датовали,
# ----
# iter 24800, loss: 71.216908
# ----
#   Скажи.
# Ве уд бомю?
# вденали не ротьсикий бь тсвчал б вулатым узромить мореть мосюди — наять нешны?
# Вуканыв ват Мышспять друга!
# Чумимых велуме гото пулы меши Богатый бым нетренись дупан ры струлой По п
# ----
# iter 24900, loss: 71.126584
# ----
#   Ске!
# Ктараны бцулие?
# В срди?
# И вда рогы!
# Чудисмять отдани лебия
# Про? дерь мыкятый Мортолчатуе кударум чиа чет грашы?
# Тобыщи пожруть моднезам китовин
# Ни?
# Сме гов ко вал сяж
# Не бониват…
# Зеиля не зарсем
# ----
# iter 25000, loss: 70.982128
# ----
#   Скеспамке?
# Слых, жени
# Сламбя:
# Нешку, пораны исталк хутрускватари:
# «Чбоваля:
# Еста кват русь вин сздинцау велен
# Мым кебылус потя:
# Быле бодина! —
# И дна мрожал тешле.
# Чт..
# Тотдизали ры земдны былив булис
# ----
# iter 25100, loss: 71.325398
# ----
#   Скаь сали нале
# И ветросмежья как там мулойУ мвенжали,
# Д, семажци слебиныль утаку.
# Нюми?
# Свень от жея засдатал:, трресместь — кораши:
# Вротсрау волесь — нгашог вой!»
# На богим зпашль креть я вкретцужит,
# ----
# iter 25200, loss: 71.280282
# ----
#   Скесь мы тратае
# Гретребы?
# И донум чаки,
# Мовдая прокашк буди лылитсли,
# Фрнул кале тоюди,
# «Ретен!
# Пои ю!
# Прим дреную.
# Тотеды.
# Уласа:
# Врог за респоражь.
# Мы огдаш б дина, готромиты цудила!
# И до! — верик
#
# ----
# iter 25300, loss: 71.166582
# ----
#   Скет закотанцузисчь нались стечим онспы.
# Ве жеменал, —
# Френим ссжения
# Р кеди — мажьна, лемне:
# «гаррог,
# Длебий…шиль спакана ветьить сь Мумвалку вслог ту лой.
# Пже ручак убись осте лной.
# На векона
# И яз
# ----
# iter 25400, loss: 71.166058
# ----
#   Ска
# Понскдо студи мог:, достки, можда!
# Ка важьрала бав пя?
# ; ню, омакь на зболивали говретлыха,
# На сред дочналушось остемумем мя ж не далять…
# Ддаремия — печи
# Не не гоМо тены.
# У мтечРой дро…
# Зва мучал
# ----
# iter 25500, loss: 71.141017
# ----
#   Скаюцуй веретерщал най выл на,
# И чут рлне шоюшкиа сещь мочас мамих нылисужал у мина, картечнали кути?»
# ИНетумж ныжичи!
# И не, прлге:
# Богота потой бынцу жичи кое порят, ледьльй!ь — пут хтетна, етреть.
#
# ----
# iter 25600, loss: 71.191610
# ----
#   Скат налие кюдия дарих пначнавил фоетик
# И кафетали хледня по терищеть тыля одреднь стретнут мы стачи:
# «гоу в новал затой,
# Кускиак той на бытосшныя битыти
# И жолы
# И двы осквеят.
# Да цударжна ры потой,
# К
# ----
# iter 25700, loss: 70.976263
# ----
#   Скет нами?
# И влась — невау
# Куката,
# Времула
# Всяль не бып кодаш лжен бы? молькая Рый бый!..
# Товаш срами?
# Немади б коваш родь на учу котйцут.
# За шимним бый!нив дик,
# И дашать.
# Де смит
# Мосюдио
# «гозва омно
# ----
# iter 25800, loss: 70.931521
# ----
#   Скалруча!
# бцос вил пудап озЧтыт коньве коячал темушк хва с пром зебде куты.
# Протя,
# Нам были шелесьлау,
# Всольсь в схвеетьки мусхя — веный
# И лись дорыж
# Мободилучерыл,
# И яла еральжали мыл от.
# И стересьр
# ----
# iter 25900, loss: 70.986224
# ----
#   Скаля сгдан ры сравы,
# Забою!
# Сквары,
# Валка,
# Да, карою,
# Фнаныл,
# И недна цготре медень — метен не пуна, бугой…
# Звашко
# Пону полий
# Улись,ь ниесь — наш боет.
# И вгат…
# Ва вредья:
# Нечи!
# Посекатц, мычне? севе
# ----
# iter 26000, loss: 70.991280
# ----
#   Скети
#
# Чуюман бы, бырый МыМыло нцдупумы,
# Твотьсик ячь сылиту п огде в унень ось до мролтольшы:
# Ве кодаутсь — нечий
# Сроссьвелки бельхутал ферн—
# Нак еташ сгаум нашноский бы бостимилше букаа, пронать —
# ----
# iter 26100, loss: 70.729931
# ----
#   Скажае слебулим Бы,,
# Ва рудань стали мспилослизь с ковая боските!
# Чуредныте мучема, быку…
# Во, всю!
# Чтои ждит:
# Все в ломуть — моять не бодь вы?
# И наше наль,
# И веднут ? дори?
# Карийцуе вола цагол:и лемч
# ----
# iter 26200, loss: 70.427825
# ----
#   Скели таш вогясДли следенало уть тостами вяд я тризвалаг о мальратир тесьшнусы ускваный:
# Кташкена,
# В, зе деднал сьшань — кломуе сяла счакь на в Бы, зась Ботлицспя огва, ковай усговаки жРюй!
# Неть свет
# ----
# iter 26300, loss: 70.644378
# ----
#   Скелись вол мы мистали,
# Момяторжущылкх язомкутссть.
# Тодни тыю!
# И ж вы,
# Во добатиМ сме рутой кой был были,
# Коврей
# Плруюча на вола бьдий»
# Не на бие голцит жашка,
# Да, стети,
# В, в Быто ядурот еть Бот зым
# ----
# iter 26400, loss: 70.644145
# ----
#   Скаты!
# И лов петола,
# Времесь дил:
# «Что мыштыл:, стали,
# С помнилы, бодеМы,
# И вдат накиЗа стежили,
# И язаля: сядура,
# Кта булабуты.
# Да, пошя жан билоКеми?
# И коя прузарнаш бугерГсерденак!
# И смегола врат б
# ----
# iter 26500, loss: 70.565544
# ----
#   Скех пнуштости — недис
# В стате
# Товдат рять — Ралцолойцуй стлеми,
# Нерзалге,
# Вза стали Дра места,
# Рну поть,
# И ю! быя Мостари:
# «Реб дить мы стали Да! недьолись.
# Усая прогопы зе дале
# Чтоля Се былы гою,
# К
# ----
# iter 26600, loss: 70.493040
# ----
#   Ска
# боразо машульсмали:
# «Рдучи,
# И вдарте…
# Д,, вою!
# Молись вал булий
# Промкни страшной.
# Не м лыху, коранО не озРятод ны бупирог я веремечарары,
# Гвар ечилы хута?
# Врог удик на волемы.
# Да, были зот обова
# ----
# iter 26700, loss: 70.293735
# ----
#   Скачи ворто тотымусхвил.
# В скралы,
# Товаражий
# И лка ратоять…
# Мы бовая:
# И валя,
# Москвань се простьле —
# Восешие геторик
# И нжал!
# И едрум неть ятовя пожетан зашеньстатами,
# Ну слка, боваю!
# Драть,
# Зак троля
# ----
# iter 26800, loss: 70.083478
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 18
#      15   print('----\n %s \n----' % (txt, ))
#      17 # forward seq_length characters through the net and fetch gradient
# ---> 18 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      19 smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      20 if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# Cell In[31], line 30, in lossFun(inputs, targets, hprev)
#      28 dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
#      29 dbh += dhraw
# ---> 30 dWxh += np.dot(dhraw, xs[t].T)
#      31 dWhh += np.dot(dhraw, hs[t-1].T)
#      32 dhnext = np.dot(Whh.T, dhraw)
#
# File ~/anaconda3/lib/python3.12/site-packages/numpy/core/multiarray.py:741, in dot(a, b, out)
#     671     """
#     672     result_type(*arrays_and_dtypes)
#     673
#    (...)
#     736
#     737     """
#     738     return arrays_and_dtypes
# --> 741 @array_function_from_c_func_and_dispatcher(_multiarray_umath.dot)
#     742 def dot(a, b, out=None):
#     743     """
#     744     dot(a, b, out=None)
#     745
#    (...)
#     829
#     830     """
#     831     return (a, b, out)
#
# KeyboardInterrupt:
